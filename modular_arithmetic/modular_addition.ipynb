# %% [markdown]
# #
# RLCT Estimation of Sorting
#
# This Jupyter Notebook aims to measure the Real Log Canonical Threshold (RLCT) for a small 3-layer transformer model (~280,000 parameters) trained to sort sequences of 20 digits consisting of the numbers 0-19. It uses both Stochastic Gradient Nose-Hoover Thermostat (SGNHT) and Stochastic Gradient Langevin Dynamics (SGLD) as sampling methods.
#
# ## Main Steps:
#
# 1. **Data Preparation**: Generate the dataset of numbers to sort.
# 2. **Model Training**: Train a transformer model using stochastic gradient descent.
# 3. **Model Evaluation**: Evaluate the model's performance on a test set.
# 4. **RLCT Estimation**: Use SGNHT and SGLD samplers to estimate RLCT.
# 5. **Plotting**: Visualize train and test losses, and RLCT estimates.

# %%
# %pip install devinterp seaborn torchvision pickleshare wandb plotly einops
# !git clone https://github.com/ucla-vision/entropy-sgd.git
# %cd entropy-sgd
from python.optim import EntropySGD
# %cd ..
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: devinterp in ./.local/lib/python3.10/site-packages (0.2.2)
# Requirement already satisfied: seaborn in ./.local/lib/python3.10/site-packages (0.13.2)
# Requirement already satisfied: torchvision in /gpfs/admin/_hpc/sw/arch/INTEL-AVX512/RHEL8/EB_production/2022/software/torchvision/0.13.1-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages (0.13.1)
# Requirement already satisfied: pickleshare in /gpfs/admin/_hpc/sw/arch/INTEL-AVX512/RHEL8/EB_production/2022/software/IPython/8.5.0-GCCcore-11.3.0/lib/python3.10/site-packages (0.7.5)
# Requirement already satisfied: wandb in ./.local/lib/python3.10/site-packages (0.17.3)
# Requirement already satisfied: plotly in ./.local/lib/python3.10/site-packages (5.22.0)
# Requirement already satisfied: einops in ./.local/lib/python3.10/site-packages (0.8.0)
# Collecting torch>=2.0.1
#   Using cached torch-2.3.1-cp310-cp310-manylinux1_x86_64.whl (779.1 MB)
# Collecting pandas>=1.5.3
#   Using cached pandas-2.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.0 MB)
# Collecting scipy>=1.10.1
#   Using cached scipy-1.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (41.1 MB)
# Requirement already satisfied: tqdm>=4.65.0 in ./.local/lib/python3.10/site-packages (from devinterp) (4.66.4)
# Collecting numpy>=1.23.5
#   Using cached numpy-2.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (19.3 MB)
# Collecting matplotlib>=3.7.5
#   Using cached matplotlib-3.9.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
# Requirement already satisfied: requests in /gpfs/admin/_hpc/sw/arch/INTEL-AVX512/RHEL8/EB_production/2022/software/Python/3.10.4-GCCcore-11.3.0/lib/python3.10/site-packages (from torchvision) (2.27.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /gpfs/admin/_hpc/sw/arch/INTEL-AVX512/RHEL8/EB_production/2022/software/Pillow-SIMD/9.2.0-GCCcore-11.3.0/lib/python3.10/site-packages (from torchvision) (9.2.0)
# Requirement already satisfied: typing-extensions in ./.local/lib/python3.10/site-packages (from torchvision) (4.12.2)
# Collecting torchvision
#   Using cached torchvision-0.18.1-cp310-cp310-manylinux1_x86_64.whl (7.0 MB)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in ./.local/lib/python3.10/site-packages (from torch>=2.0.1->devinterp) (10.3.2.106)
# Requirement already satisfied: jinja2 in /gpfs/admin/_hpc/sw/arch/INTEL-AVX512/RHEL8/EB_production/2022/software/Python/3.10.4-GCCcore-11.3.0/lib/python3.10/site-packages (from torch>=2.0.1->devinterp) (3.1.2)
# Requirement already satisfied: sympy in ./.local/lib/python3.10/site-packages (from torch>=2.0.1->devinterp) (1.12.1)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in ./.local/lib/python3.10/site-packages (from torch>=2.0.1->devinterp) (8.9.2.26)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in ./.local/lib/python3.10/site-packages (from torch>=2.0.1->devinterp) (11.4.5.107)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in ./.local/lib/python3.10/site-packages (from torch>=2.0.1->devinterp) (12.1.105)
# Requirement already satisfied: networkx in /gpfs/admin/_hpc/sw/arch/INTEL-AVX512/RHEL8/EB_production/2022/software/networkx/2.8.4-foss-2022a/lib/python3.10/site-packages (from torch>=2.0.1->devinterp) (2.8.4)
# Requirement already satisfied: filelock in /gpfs/admin/_hpc/sw/arch/INTEL-AVX512/RHEL8/EB_production/2022/software/Python/3.10.4-GCCcore-11.3.0/lib/python3.10/site-packages (from torch>=2.0.1->devinterp) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in ./.local/lib/python3.10/site-packages (from torch>=2.0.1->devinterp) (12.1.3.1)
# Requirement already satisfied: fsspec in /gpfs/admin/_hpc/sw/arch/INTEL-AVX512/RHEL8/EB_production/2022/software/Python/3.10.4-GCCcore-11.3.0/lib/python3.10/site-packages (from torch>=2.0.1->devinterp) (2022.3.0)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in ./.local/lib/python3.10/site-packages (from torch>=2.0.1->devinterp) (12.1.0.106)
# Requirement already satisfied: triton==2.3.1 in ./.local/lib/python3.10/site-packages (from torch>=2.0.1->devinterp) (2.3.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in ./.local/lib/python3.10/site-packages (from torch>=2.0.1->devinterp) (2.20.5)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in ./.local/lib/python3.10/site-packages (from torch>=2.0.1->devinterp) (12.1.105)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in ./.local/lib/python3.10/site-packages (from torch>=2.0.1->devinterp) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in ./.local/lib/python3.10/site-packages (from torch>=2.0.1->devinterp) (12.1.105)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in ./.local/lib/python3.10/site-packages (from torch>=2.0.1->devinterp) (11.0.2.54)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in ./.local/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=2.0.1->devinterp) (12.5.40)
# Requirement already satisfied: pyyaml in /gpfs/admin/_hpc/sw/arch/INTEL-AVX512/RHEL8/EB_production/2022/software/PyYAML/6.0-GCCcore-11.3.0/lib/python3.10/site-packages (from wandb) (6.0)
# Requirement already satisfied: sentry-sdk>=1.0.0 in ./.local/lib/python3.10/site-packages (from wandb) (2.7.1)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in ./.local/lib/python3.10/site-packages (from wandb) (3.1.43)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /gpfs/admin/_hpc/sw/arch/INTEL-AVX512/RHEL8/EB_production/2022/software/Python/3.10.4-GCCcore-11.3.0/lib/python3.10/site-packages (from wandb) (8.1.3)
# Requirement already satisfied: platformdirs in /gpfs/admin/_hpc/sw/arch/INTEL-AVX512/RHEL8/EB_production/2022/software/Python/3.10.4-GCCcore-11.3.0/lib/python3.10/site-packages (from wandb) (2.4.1)
# Requirement already satisfied: docker-pycreds>=0.4.0 in ./.local/lib/python3.10/site-packages (from wandb) (0.4.0)
# Requirement already satisfied: setuptools in /gpfs/admin/_hpc/sw/arch/INTEL-AVX512/RHEL8/EB_production/2022/software/Python/3.10.4-GCCcore-11.3.0/lib/python3.10/site-packages (from wandb) (62.1.0)
# Requirement already satisfied: setproctitle in ./.local/lib/python3.10/site-packages (from wandb) (1.3.3)
# Requirement already satisfied: protobuf!=4.21.0,<6,>=3.19.0 in /gpfs/admin/_hpc/sw/arch/INTEL-AVX512/RHEL8/EB_production/2022/software/protobuf-python/3.19.4-GCCcore-11.3.0/lib/python3.10/site-packages (from wandb) (3.19.4)
# Requirement already satisfied: psutil>=5.0.0 in /gpfs/admin/_hpc/sw/arch/INTEL-AVX512/RHEL8/EB_production/2022/software/Python/3.10.4-GCCcore-11.3.0/lib/python3.10/site-packages (from wandb) (5.9.0)
# Requirement already satisfied: packaging in /gpfs/admin/_hpc/sw/arch/INTEL-AVX512/RHEL8/EB_production/2022/software/Python/3.10.4-GCCcore-11.3.0/lib/python3.10/site-packages (from plotly) (20.9)
# Requirement already satisfied: tenacity>=6.2.0 in ./.local/lib/python3.10/site-packages (from plotly) (8.4.2)
# Requirement already satisfied: six>=1.4.0 in /gpfs/admin/_hpc/sw/arch/INTEL-AVX512/RHEL8/EB_production/2022/software/Python/3.10.4-GCCcore-11.3.0/lib/python3.10/site-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in ./.local/lib/python3.10/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.11)
# Requirement already satisfied: kiwisolver>=1.3.1 in /gpfs/admin/_hpc/sw/arch/INTEL-AVX512/RHEL8/EB_production/2022/software/matplotlib/3.5.2-foss-2022a/lib/python3.10/site-packages (from matplotlib>=3.7.5->devinterp) (1.4.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /gpfs/admin/_hpc/sw/arch/INTEL-AVX512/RHEL8/EB_production/2022/software/Python/3.10.4-GCCcore-11.3.0/lib/python3.10/site-packages (from matplotlib>=3.7.5->devinterp) (3.0.8)
# Requirement already satisfied: fonttools>=4.22.0 in /gpfs/admin/_hpc/sw/arch/INTEL-AVX512/RHEL8/EB_production/2022/software/matplotlib/3.5.2-foss-2022a/lib/python3.10/site-packages (from matplotlib>=3.7.5->devinterp) (4.34.0)
# Requirement already satisfied: cycler>=0.10 in /gpfs/admin/_hpc/sw/arch/INTEL-AVX512/RHEL8/EB_production/2022/software/matplotlib/3.5.2-foss-2022a/lib/python3.10/site-packages (from matplotlib>=3.7.5->devinterp) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /gpfs/admin/_hpc/sw/arch/INTEL-AVX512/RHEL8/EB_production/2022/software/Python/3.10.4-GCCcore-11.3.0/lib/python3.10/site-packages (from matplotlib>=3.7.5->devinterp) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in ./.local/lib/python3.10/site-packages (from matplotlib>=3.7.5->devinterp) (1.2.1)
# Requirement already satisfied: pytz>=2020.1 in /gpfs/admin/_hpc/sw/arch/INTEL-AVX512/RHEL8/EB_production/2022/software/Python/3.10.4-GCCcore-11.3.0/lib/python3.10/site-packages (from pandas>=1.5.3->devinterp) (2022.1)
# Requirement already satisfied: tzdata>=2022.7 in ./.local/lib/python3.10/site-packages (from pandas>=1.5.3->devinterp) (2024.1)
# Requirement already satisfied: certifi>=2017.4.17 in /gpfs/admin/_hpc/sw/arch/INTEL-AVX512/RHEL8/EB_production/2022/software/Python/3.10.4-GCCcore-11.3.0/lib/python3.10/site-packages (from requests->torchvision) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /gpfs/admin/_hpc/sw/arch/INTEL-AVX512/RHEL8/EB_production/2022/software/Python/3.10.4-GCCcore-11.3.0/lib/python3.10/site-packages (from requests->torchvision) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./.local/lib/python3.10/site-packages (from requests->torchvision) (1.26.19)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /gpfs/admin/_hpc/sw/arch/INTEL-AVX512/RHEL8/EB_production/2022/software/Python/3.10.4-GCCcore-11.3.0/lib/python3.10/site-packages (from requests->torchvision) (2.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in ./.local/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /gpfs/admin/_hpc/sw/arch/INTEL-AVX512/RHEL8/EB_production/2022/software/Python/3.10.4-GCCcore-11.3.0/lib/python3.10/site-packages (from jinja2->torch>=2.0.1->devinterp) (2.1.1)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /gpfs/admin/_hpc/sw/arch/INTEL-AVX512/RHEL8/EB_production/2022/software/SciPy-bundle/2022.05-foss-2022a/lib/python3.10/site-packages (from sympy->torch>=2.0.1->devinterp) (1.2.1)
# Installing collected packages: numpy, scipy, pandas, torch, matplotlib, torchvision
#   WARNING: The scripts f2py and numpy-config are installed in '/home/bshaffrey/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts convert-caffe2-to-onnx, convert-onnx-to-caffe2 and torchrun are installed in '/home/bshaffrey/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.11.0 requires gast<=0.4.0,>=0.2.1, but you have gast 0.5.3 which is incompatible.
# Successfully installed matplotlib-3.9.0 numpy-2.0.0 pandas-2.2.2 scipy-1.14.0 torch-2.3.1 torchvision-0.18.1
# WARNING: You are using pip version 22.0.4; however, version 24.1.1 is available.
# You should consider upgrading via the '/sw/arch/RHEL8/EB_production/2022/software/Python/3.10.4-GCCcore-11.3.0/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# fatal: destination path 'entropy-sgd' already exists and is not an empty directory.
# /gpfs/home1/bshaffrey/entropy-sgd
# /gpfs/home1/bshaffrey

# %%
import numpy as np
import torch as t
import torch
import torch.nn as nn
import torch.optim as optim
import time
import torch.nn.functional as F
import einops
import random
import helpers
from transformers import *
from dataclasses import dataclass
import os
import copy
import wandb
from tqdm.notebook import tqdm
import seaborn as sns
import matplotlib.pyplot as plt
from python.optim import EntropySGD
from torch.utils.data import DataLoader

from devinterp.optim.sgld import SGLD
from devinterp.optim.sgnht import SGNHT

PRIMARY, SECONDARY, TERTIARY, QUATERNARY = sns.color_palette("muted")[:4]
PRIMARY_LIGHT, SECONDARY_LIGHT, TERTIARY_LIGHT, QUATERNARY_LIGHT = sns.color_palette(
    "pastel"
)[:4]

# %%
def accuracy_function(outputs, targets):
    return (outputs[ : , -1].argmax(1) == targets).float().mean()

def do_a_training_step(model, train_data, test_data, optimizer, scheduler, epoch: int):
        '''returns train_loss, test_loss'''
        model.train()
        train_loss = full_loss(config = config, model = model, data = train_data)
        #self.train_losses.append(train_loss.item())
        #self.test_losses.append(test_loss.item())
        optimizer.zero_grad()
        train_loss.backward()
        optimizer.step()
        scheduler.step()
        model.eval()  # Set model to evaluation mode
        with torch.no_grad():  # Disable gradient calculation for test
          test_loss = full_loss(config=config, model=model, data=test_data)
        if epoch % 100 == 0:
            # TODO is this ok? this was np.log, and it was barking at me ; i think np.log was being interpreted as a logging module
            print(f'Epoch {epoch}, train loss {t.log(train_loss).item():.4f}, test loss {t.log(test_loss).item():.4f}')

        return train_loss.detach(), test_loss.detach()

def train_one_epoch(model, train_loader, optimizer, scheduler, criterion, model_key):

    model.train()
    train_loss = 0
    train_accuracy = 0
    for index, (data, targets) in enumerate(train_loader):
        optimizer.zero_grad()
        outputs = model(data.to(DEVICE))
        loss = criterion(outputs, targets.to(DEVICE))
        train_loss += loss.item()
        train_accuracy += accuracy_function(outputs, targets.to(DEVICE))
        loss.backward()
        optimizer.step()
        scheduler.step()

    return train_loss / len(train_loader), train_accuracy / len(train_loader)


def evaluate(model, test_loader, criterion):
    model.eval()
    test_loss = 0
    test_accuracy = 0
    with torch.no_grad():
        for index, (data, targets) in enumerate(test_loader):
            outputs = model(data.to(DEVICE))
            loss = criterion(outputs, targets.to(DEVICE))
            test_loss += loss.item()
            test_accuracy += accuracy_function(outputs, targets.to(DEVICE))

    return test_loss / len(test_loader), test_accuracy / len(test_loader)

# %%
# Constants
DEVICE = "cuda" if t.cuda.is_available() else "cpu"
BATCH_SIZE = 16384
LR = 1e-4
N_EPOCHS = 10000
config = Config()

def get_data(config : Config):
    num_to_generate = config.p
    pairs = [(i, j, num_to_generate) for i in range(num_to_generate) for j in range(num_to_generate)]
    random.seed(config.seed)
    random.shuffle(pairs)
    div = int(config.frac_train*len(pairs))
    labels = [config.fn(i, j) for i, j, _ in pairs]
    pairs = t.tensor(pairs).long()
    labels = t.tensor(labels).long()
    train_data = list(zip(pairs[:div], labels[:div]))
    test_data = list(zip(pairs[div:], labels[div:]))
    return train_data, test_data

train_data, test_data = get_data(config = config)
train_loader = torch.utils.data.DataLoader(train_data, batch_size=BATCH_SIZE, shuffle=True, pin_memory=True)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=BATCH_SIZE, shuffle=False, pin_memory=True)
criterion = helpers.cross_entropy_high_precision
print(len(train_loader))
print(len(test_loader))
print(len(train_data))
print(len(test_data))
print(torch.cuda.is_available())
# Out:
# 1
# 1
# 3830
# 8939
# True

# %%
def train_models(train_data, test_data, runs):
    train_losses = torch.zeros(runs, N_EPOCHS)
    test_losses = torch.zeros(runs, N_EPOCHS)
    train_accuracies = torch.zeros(runs, N_EPOCHS)
    test_accuracies = torch.zeros(runs, N_EPOCHS)
    models_saved = []
    for run in tqdm(range(runs)):
        model = Transformer(config, use_cache=False)
        model.to(config.device)
        optimizer = optim.AdamW(model.parameters(), lr = config.lr, weight_decay=config.weight_decay, betas=(0.9, 0.98))
        scheduler = optim.lr_scheduler.LambdaLR(optimizer, lambda step: min(step/10, 1)) # TODO make this a config option
        for epoch in tqdm(range(N_EPOCHS)):
            train_loss, train_accuracy = train_one_epoch(
                model, train_loader, optimizer, scheduler, criterion, 'sgd'
            )
            test_loss, test_accuracy = evaluate(model, test_loader, criterion)
            train_losses[run, epoch] = train_loss
            test_losses[run, epoch] = test_loss
            train_accuracies[run, epoch] = train_accuracy
            test_accuracies[run, epoch] = test_accuracy
            models_saved += [copy.deepcopy(model)]
            if epoch % 100 == 0:
              print(
                  f"Epoch {epoch+1}, Model {'sgd'.upper()} Train Loss: {train_loss}, Test Loss: {test_loss}", '\n',
                  f"Epoch {epoch+1}, Model {'sgd'.upper()} Train Accuracy: {train_accuracy}, Test Accuracy: {test_accuracy}"
              )

    train_losses_final = train_losses.mean(dim=0)
    test_losses_final = test_losses.mean(dim=0)
    train_accuracies_final = train_accuracies.mean(dim=0)
    test_accuracies_final = test_accuracies.mean(dim=0)
    torch.cuda.empty_cache()

    return train_losses_final, test_losses_final, train_accuracies_final, test_accuracies_final, models_saved

torch.cuda.empty_cache()
runs = 1
train_losses_final, test_losses_final, train_accuracies_final, test_accuracies_final, models_saved = train_models(train_loader, test_loader, runs)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/10000 [00:00<?, ?it/s]
# Epoch 1, Model SGD Train Loss: 4.767282485961914, Test Loss: 4.775090217590332
#  Epoch 1, Model SGD Train Accuracy: 0.007832897827029228, Test Accuracy: 0.007271507289260626
# Epoch 101, Model SGD Train Loss: 2.3784656524658203, Test Loss: 7.692261695861816
#  Epoch 101, Model SGD Train Accuracy: 0.45091384649276733, Test Accuracy: 0.0111869340762496
# Epoch 201, Model SGD Train Loss: 0.020632406696677208, Test Loss: 16.356964111328125
#  Epoch 201, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.028414811939001083
# Epoch 301, Model SGD Train Loss: 0.007399916648864746, Test Loss: 16.79149627685547
#  Epoch 301, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.0314352847635746
# Epoch 401, Model SGD Train Loss: 0.0024022452998906374, Test Loss: 17.727237701416016
#  Epoch 401, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.034903235733509064
# Epoch 501, Model SGD Train Loss: 0.0007990992162376642, Test Loss: 18.757173538208008
#  Epoch 501, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.039489876478910446
# Epoch 601, Model SGD Train Loss: 0.0002703219070099294, Test Loss: 19.830259323120117
#  Epoch 601, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.04251034930348396
# Epoch 701, Model SGD Train Loss: 9.263215179089457e-05, Test Loss: 20.929723739624023
#  Epoch 701, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.044523999094963074
# Epoch 801, Model SGD Train Loss: 3.2242187444353476e-05, Test Loss: 22.02142906188965
#  Epoch 801, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.04698512330651283
# Epoch 901, Model SGD Train Loss: 1.1527804417710286e-05, Test Loss: 23.082422256469727
#  Epoch 901, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.050341203808784485
# Epoch 1001, Model SGD Train Loss: 4.3370287130528595e-06, Test Loss: 24.052127838134766
#  Epoch 1001, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.051571764051914215
# Epoch 1101, Model SGD Train Loss: 1.7714232853904832e-06, Test Loss: 24.896717071533203
#  Epoch 1101, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.05246672034263611
# Epoch 1201, Model SGD Train Loss: 8.558787385481992e-07, Test Loss: 25.479787826538086
#  Epoch 1201, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.05369728431105614
# Epoch 1301, Model SGD Train Loss: 5.174864554646774e-07, Test Loss: 25.75539779663086
#  Epoch 1301, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.05470410734415054
# Epoch 1401, Model SGD Train Loss: 4.090465495210083e-07, Test Loss: 25.638498306274414
#  Epoch 1401, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.056046538054943085
# Epoch 1501, Model SGD Train Loss: 3.711983538323693e-07, Test Loss: 25.399824142456055
#  Epoch 1501, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.05649401620030403
# Epoch 1601, Model SGD Train Loss: 3.580324232643761e-07, Test Loss: 25.17668342590332
#  Epoch 1601, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.05705336481332779
# Epoch 1701, Model SGD Train Loss: 3.505935239900282e-07, Test Loss: 25.074302673339844
#  Epoch 1701, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.05727710202336311
# Epoch 1801, Model SGD Train Loss: 3.5653843610816693e-07, Test Loss: 25.214107513427734
#  Epoch 1801, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.05705336481332779
# Epoch 1901, Model SGD Train Loss: 0.0007123470422811806, Test Loss: 18.4799747467041
#  Epoch 1901, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.05884327366948128
# Epoch 2001, Model SGD Train Loss: 0.005654471926391125, Test Loss: 11.774483680725098
#  Epoch 2001, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.059290751814842224
# Epoch 2101, Model SGD Train Loss: 0.004946392960846424, Test Loss: 11.882774353027344
#  Epoch 2101, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.05895514041185379
# Epoch 2201, Model SGD Train Loss: 0.0019530749414116144, Test Loss: 13.19372272491455
#  Epoch 2201, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.05951448902487755
# Epoch 2301, Model SGD Train Loss: 0.0007308050990104675, Test Loss: 14.554903030395508
#  Epoch 2301, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.06164000555872917
# Epoch 2401, Model SGD Train Loss: 0.00026729286764748394, Test Loss: 15.918012619018555
#  Epoch 2401, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.06365365535020828
# Epoch 2501, Model SGD Train Loss: 9.686553676147014e-05, Test Loss: 17.252595901489258
#  Epoch 2501, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.06454861164093018
# Epoch 2601, Model SGD Train Loss: 3.51117123500444e-05, Test Loss: 18.534366607666016
#  Epoch 2601, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.06700973212718964
# Epoch 2701, Model SGD Train Loss: 1.2889063327747863e-05, Test Loss: 19.739736557006836
#  Epoch 2701, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.06790468841791153
# Epoch 2801, Model SGD Train Loss: 4.896093741990626e-06, Test Loss: 20.82898712158203
#  Epoch 2801, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.06969460099935532
# Epoch 2901, Model SGD Train Loss: 1.994496415136382e-06, Test Loss: 21.737506866455078
#  Epoch 2901, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.0723794624209404
# Epoch 3001, Model SGD Train Loss: 9.268127882933186e-07, Test Loss: 22.362590789794922
#  Epoch 3001, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.07450497895479202
# Epoch 3101, Model SGD Train Loss: 5.258591500023613e-07, Test Loss: 22.626712799072266
#  Epoch 3101, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.07774919271469116
# Epoch 3201, Model SGD Train Loss: 3.8722780004718516e-07, Test Loss: 22.499574661254883
#  Epoch 3201, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.08021031320095062
# Epoch 3301, Model SGD Train Loss: 3.8034914950912935e-07, Test Loss: 22.172800064086914
#  Epoch 3301, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.08166462182998657
# Epoch 3401, Model SGD Train Loss: 4.174814023372164e-07, Test Loss: 21.728092193603516
#  Epoch 3401, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.08222396671772003
# Epoch 3501, Model SGD Train Loss: 0.001498774392530322, Test Loss: 16.045719146728516
#  Epoch 3501, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.08625125885009766
# Epoch 3601, Model SGD Train Loss: 0.008472826331853867, Test Loss: 9.765246391296387
#  Epoch 3601, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.08882425725460052
# Epoch 3701, Model SGD Train Loss: 0.012558148242533207, Test Loss: 9.03197956085205
#  Epoch 3701, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.08725808560848236
# Epoch 3801, Model SGD Train Loss: 0.005161419045180082, Test Loss: 9.872086524963379
#  Epoch 3801, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.09117351472377777
# Epoch 3901, Model SGD Train Loss: 0.0019613979384303093, Test Loss: 10.7700777053833
#  Epoch 3901, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.09508893638849258
# Epoch 4001, Model SGD Train Loss: 0.0007220831466838717, Test Loss: 11.669758796691895
#  Epoch 4001, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.09833315014839172
# Epoch 4101, Model SGD Train Loss: 0.000261793116806075, Test Loss: 12.534324645996094
#  Epoch 4101, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.10314352810382843
# Epoch 4201, Model SGD Train Loss: 9.424354357179254e-05, Test Loss: 13.34351921081543
#  Epoch 4201, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.10728269815444946
# Epoch 4301, Model SGD Train Loss: 3.402333823032677e-05, Test Loss: 14.078481674194336
#  Epoch 4301, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.1124286875128746
# Epoch 4401, Model SGD Train Loss: 1.2467262422433123e-05, Test Loss: 14.721606254577637
#  Epoch 4401, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.11746280640363693
# Epoch 4501, Model SGD Train Loss: 4.738881671073614e-06, Test Loss: 15.264421463012695
#  Epoch 4501, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.12227319180965424
# Epoch 4601, Model SGD Train Loss: 1.9346430235600565e-06, Test Loss: 15.643476486206055
#  Epoch 4601, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.1275310516357422
# Epoch 4701, Model SGD Train Loss: 8.938512792155962e-07, Test Loss: 15.797663688659668
#  Epoch 4701, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.13469068706035614
# Epoch 4801, Model SGD Train Loss: 4.975975116394693e-07, Test Loss: 15.719038963317871
#  Epoch 4801, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.14308089017868042
# Epoch 4901, Model SGD Train Loss: 3.4832137885132397e-07, Test Loss: 15.452616691589355
#  Epoch 4901, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.1495693027973175
# Epoch 5001, Model SGD Train Loss: 3.543907780567679e-07, Test Loss: 14.943052291870117
#  Epoch 5001, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.1600850224494934
# Epoch 5101, Model SGD Train Loss: 0.0006397211109288037, Test Loss: 9.147536277770996
#  Epoch 5101, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.17026513814926147
# Epoch 5201, Model SGD Train Loss: 0.003941399045288563, Test Loss: 6.825081825256348
#  Epoch 5201, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.1752992570400238
# Epoch 5301, Model SGD Train Loss: 0.0018012586515396833, Test Loss: 7.089882850646973
#  Epoch 5301, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.18402506411075592
# Epoch 5401, Model SGD Train Loss: 0.0006748574087396264, Test Loss: 7.4095940589904785
#  Epoch 5401, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.1962188184261322
# Epoch 5501, Model SGD Train Loss: 0.0002443731063976884, Test Loss: 7.6480865478515625
#  Epoch 5501, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.21266362071037292
# Epoch 5601, Model SGD Train Loss: 8.732162677915767e-05, Test Loss: 7.751811981201172
#  Epoch 5601, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.23291195929050446
# Epoch 5701, Model SGD Train Loss: 3.10799186991062e-05, Test Loss: 7.687441825866699
#  Epoch 5701, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.2589775323867798
# Epoch 5801, Model SGD Train Loss: 1.1169756362505723e-05, Test Loss: 7.421261787414551
#  Epoch 5801, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.28537869453430176
# Epoch 5901, Model SGD Train Loss: 4.14184114561067e-06, Test Loss: 6.916012763977051
#  Epoch 5901, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.32319051027297974
# Epoch 6001, Model SGD Train Loss: 1.6356241303583374e-06, Test Loss: 6.131261825561523
#  Epoch 6001, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.3717418313026428
# Epoch 6101, Model SGD Train Loss: 7.335568170674378e-07, Test Loss: 5.110053062438965
#  Epoch 6101, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.4294663965702057
# Epoch 6201, Model SGD Train Loss: 3.979347980020975e-07, Test Loss: 3.9939701557159424
#  Epoch 6201, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.5083342790603638
# Epoch 6301, Model SGD Train Loss: 2.564399608218082e-07, Test Loss: 3.0207619667053223
#  Epoch 6301, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.5849647521972656
# Epoch 6401, Model SGD Train Loss: 2.2447444791851012e-07, Test Loss: 2.2822275161743164
#  Epoch 6401, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.6567848920822144
# Epoch 6501, Model SGD Train Loss: 0.0004147013241890818, Test Loss: 1.2189384698867798
#  Epoch 6501, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.7084685564041138
# Epoch 6601, Model SGD Train Loss: 0.0020881236996501684, Test Loss: 0.8182771801948547
#  Epoch 6601, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.7620539665222168
# Epoch 6701, Model SGD Train Loss: 0.0008673386764712632, Test Loss: 0.4886389374732971
#  Epoch 6701, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.8499832153320312
# Epoch 6801, Model SGD Train Loss: 0.00030319197685457766, Test Loss: 0.25765466690063477
#  Epoch 6801, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.9190066456794739
# Epoch 6901, Model SGD Train Loss: 0.00010388329974375665, Test Loss: 0.12878741323947906
#  Epoch 6901, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.9588320851325989
# Epoch 7001, Model SGD Train Loss: 3.537275915732607e-05, Test Loss: 0.06484852731227875
#  Epoch 7001, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.98098224401474
# Epoch 7101, Model SGD Train Loss: 1.2206807696202304e-05, Test Loss: 0.03419823944568634
#  Epoch 7101, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.9901555180549622
# Epoch 7201, Model SGD Train Loss: 4.3212598939135205e-06, Test Loss: 0.018563171848654747
#  Epoch 7201, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.9942947030067444
# Epoch 7301, Model SGD Train Loss: 1.617226757844037e-06, Test Loss: 0.00970778800547123
#  Epoch 7301, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.9965320825576782
# Epoch 7401, Model SGD Train Loss: 6.783715775782184e-07, Test Loss: 0.004784280899912119
#  Epoch 7401, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.9983220100402832
# Epoch 7501, Model SGD Train Loss: 3.363069538409036e-07, Test Loss: 0.0023221115116029978
#  Epoch 7501, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.9995525479316711
# Epoch 7601, Model SGD Train Loss: 1.999478485004147e-07, Test Loss: 0.0009905806509777904
#  Epoch 7601, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.9996644258499146
# Epoch 7701, Model SGD Train Loss: 1.3122355824179976e-07, Test Loss: 0.00033669068943709135
#  Epoch 7701, Model SGD Train Accuracy: 1.0, Test Accuracy: 1.0
# Epoch 7801, Model SGD Train Loss: 0.0005366813857108355, Test Loss: 0.14221559464931488
#  Epoch 7801, Model SGD Train Accuracy: 1.0, Test Accuracy: 0.9556997418403625
# Epoch 7901, Model SGD Train Loss: 0.0001983843103516847, Test Loss: 0.001644903444685042
#  Epoch 7901, Model SGD Train Accuracy: 1.0, Test Accuracy: 1.0
# Epoch 8001, Model SGD Train Loss: 0.0007753534009680152, Test Loss: 0.0031943151261657476
#  Epoch 8001, Model SGD Train Accuracy: 1.0, Test Accuracy: 1.0
# Epoch 8101, Model SGD Train Loss: 0.00031468464294448495, Test Loss: 0.0016049323603510857
#  Epoch 8101, Model SGD Train Accuracy: 1.0, Test Accuracy: 1.0
# Epoch 8201, Model SGD Train Loss: 0.00011259663733653724, Test Loss: 0.0007996741333045065
#  Epoch 8201, Model SGD Train Accuracy: 1.0, Test Accuracy: 1.0
# Epoch 8301, Model SGD Train Loss: 3.945886419387534e-05, Test Loss: 0.0004449080443009734
#  Epoch 8301, Model SGD Train Accuracy: 1.0, Test Accuracy: 1.0
# Epoch 8401, Model SGD Train Loss: 1.379832156089833e-05, Test Loss: 0.00027216156013309956
#  Epoch 8401, Model SGD Train Accuracy: 1.0, Test Accuracy: 1.0
# Epoch 8501, Model SGD Train Loss: 4.912194071948761e-06, Test Loss: 0.0001727616909192875
#  Epoch 8501, Model SGD Train Accuracy: 1.0, Test Accuracy: 1.0
# Epoch 8601, Model SGD Train Loss: 1.8370316183791147e-06, Test Loss: 0.00010507196566322818
#  Epoch 8601, Model SGD Train Accuracy: 1.0, Test Accuracy: 1.0
# Epoch 8701, Model SGD Train Loss: 7.513288551308506e-07, Test Loss: 6.237047637114301e-05
#  Epoch 8701, Model SGD Train Accuracy: 1.0, Test Accuracy: 1.0
# Epoch 8801, Model SGD Train Loss: 3.5476418247526453e-07, Test Loss: 3.8402889913413674e-05
#  Epoch 8801, Model SGD Train Accuracy: 1.0, Test Accuracy: 1.0
# Epoch 8901, Model SGD Train Loss: 1.9260231454154564e-07, Test Loss: 2.2977845219429582e-05
#  Epoch 8901, Model SGD Train Accuracy: 1.0, Test Accuracy: 1.0
# Epoch 9001, Model SGD Train Loss: 0.0005757278413511813, Test Loss: 0.00486408919095993
#  Epoch 9001, Model SGD Train Accuracy: 0.999738872051239, Test Accuracy: 0.9984338879585266
# Epoch 9101, Model SGD Train Loss: 0.00012030763900838792, Test Loss: 0.00036529230419546366
#  Epoch 9101, Model SGD Train Accuracy: 1.0, Test Accuracy: 1.0
# Epoch 9201, Model SGD Train Loss: 0.00047475096653215587, Test Loss: 0.0010826500365510583
#  Epoch 9201, Model SGD Train Accuracy: 1.0, Test Accuracy: 1.0
# Epoch 9301, Model SGD Train Loss: 0.00019297549442853779, Test Loss: 0.0005423199036158621
#  Epoch 9301, Model SGD Train Accuracy: 1.0, Test Accuracy: 1.0
# Epoch 9401, Model SGD Train Loss: 7.045111851766706e-05, Test Loss: 0.000246974581386894
#  Epoch 9401, Model SGD Train Accuracy: 1.0, Test Accuracy: 1.0
# Epoch 9501, Model SGD Train Loss: 2.5243072741432115e-05, Test Loss: 0.00011339336197124794
#  Epoch 9501, Model SGD Train Accuracy: 1.0, Test Accuracy: 1.0
# Epoch 9601, Model SGD Train Loss: 9.050224434759002e-06, Test Loss: 5.2497449360089377e-05
#  Epoch 9601, Model SGD Train Accuracy: 1.0, Test Accuracy: 1.0
# Epoch 9701, Model SGD Train Loss: 3.3120400075858925e-06, Test Loss: 2.4865214072633535e-05
#  Epoch 9701, Model SGD Train Accuracy: 1.0, Test Accuracy: 1.0
# Epoch 9801, Model SGD Train Loss: 1.2789915899702464e-06, Test Loss: 1.229795907420339e-05
#  Epoch 9801, Model SGD Train Accuracy: 1.0, Test Accuracy: 1.0
# Epoch 9901, Model SGD Train Loss: 5.520972763406462e-07, Test Loss: 6.623546141781844e-06
#  Epoch 9901, Model SGD Train Accuracy: 1.0, Test Accuracy: 1.0

# %%
from devinterp.slt import estimate_learning_coeff_with_summary

def estimate_rlcts(models, train_loader, criterion, data_length, device, num_draws):
    estimates = {"sgnht": [], "sgld": []}
    for idx, model in enumerate(tqdm(models)):
        for method, optimizer_kwargs in [
            #("sgnht", {"lr": 1e-7, "diffusion_factor": 0.01}),
            ("sgld", {"lr": 1e-5, "localization": 100.0, "noise_level": 1.0}),
        ]:
            results = estimate_learning_coeff_with_summary(
                model,
                train_loader,
                criterion=criterion,
                optimizer_kwargs=optimizer_kwargs,
                sampling_method=SGNHT if method == "sgnht" else SGLD,
                num_chains=1,
                num_draws=num_draws,
                num_burnin_steps=0,
                num_steps_bw_draws=1,
                device=device,
                seed=42
            )
            estimate = results["llc/mean"]

            # take losses from last chain for plotting
            if idx == N_EPOCHS - 1:
                losses = results['loss/trace']
            estimates[method].append(estimate)
    return estimates, losses

def obtain_rlct_estimates(train_loader, models_saved, criterion, runs):
    data_length = len(train_loader)
    rlct_estimates = {"sgnht": torch.zeros(runs, N_EPOCHS), "sgld": torch.zeros(runs, N_EPOCHS)}
    num_draws = 400
    last_chain_losses = torch.zeros(runs, num_draws)

    for run in tqdm(range(runs)):
        rlct_estimate, losses = estimate_rlcts(
            models_saved[N_EPOCHS * run : N_EPOCHS * (run + 1)], train_loader, criterion, data_length, DEVICE, num_draws
        )
        #rlct_estimates["sgnht"][run] = torch.tensor(rlct_estimate["sgnht"])
        rlct_estimates["sgld"][run] = torch.tensor(rlct_estimate["sgld"])
        last_chain_losses[run] = torch.tensor(losses)

    rlct_estimates_final = {"sgnht": rlct_estimates["sgnht"].mean(dim=0), "sgld": rlct_estimates["sgld"].mean(dim=0)}
    return rlct_estimates_final, last_chain_losses.mean(dim=0)

rlct_estimates_final, last_chain_losses_final = obtain_rlct_estimates(train_loader, models_saved, criterion, runs)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/10000 [00:00<?, ?it/s]
# /home/bshaffrey/.local/lib/python3.10/site-packages/devinterp/slt/sampler.py:166: UserWarning: You are taking more draws than burn-in steps, your LLC estimates will likely be underestimates. Please check LLC chain convergence.
#   warnings.warn(
# /home/bshaffrey/.local/lib/python3.10/site-packages/devinterp/slt/sampler.py:170: UserWarning: You are taking more sample batches than there are dataloader batches available, this removes some randomness from sampling but is probably fine. (All sample batches beyond the number dataloader batches are cycled from the start, f.e. 9 samples from [A, B, C] would be [B, A, C, B, A, C, B, A, C].)
#   warnings.warn(
# /home/bshaffrey/.local/lib/python3.10/site-packages/devinterp/slt/sampler.py:189: UserWarning: You are using seeded runs, for full reproducibility check https://pytorch.org/docs/stable/notes/randomness.html
#   warnings.warn(
# /home/bshaffrey/.local/lib/python3.10/site-packages/devinterp/slt/sampler.py:54: UserWarning: You are taking more sample batches than there are dataloader batches available, this removes some randomness from sampling but is probably fine. (All sample batches beyond the number dataloader batches are cycled from the start, f.e. 9 samples from [A, B, C] would be [B, A, C, B, A, C, B, A, C].)
#   warnings.warn(
#
#
# Chain 0:   0%|          | 0/400 [00:00<?, ?it/s]
#
# Chain 0:   3%|▎         | 12/400 [00:00<00:03, 114.13it/s]
#
# Chain 0:   6%|▋         | 25/400 [00:00<00:03, 118.69it/s]
#
# Chain 0:  10%|▉         | 38/400 [00:00<00:03, 120.17it/s]
#
# Chain 0:  13%|█▎        | 51/400 [00:00<00:02, 120.82it/s]
#
# Chain 0:  16%|█▌        | 64/400 [00:00<00:02, 121.24it/s]
#
# Chain 0:  19%|█▉        | 77/400 [00:00<00:02, 121.42it/s]
#
# Chain 0:  22%|██▎       | 90/400 [00:00<00:02, 121.48it/s]
#
# Chain 0:  26%|██▌       | 103/400 [00:00<00:02, 121.66it/s]
#
# Chain 0:  29%|██▉       | 116/400 [00:00<00:02, 121.74it/s]
#
# Chain 0:  32%|███▏      | 129/400 [00:01<00:02, 121.85it/s]
#
# Chain 0:  36%|███▌      | 142/400 [00:01<00:02, 121.97it/s]
#
# Chain 0:  39%|███▉      | 155/400 [00:01<00:02, 122.11it/s]
#
# Chain 0:  42%|████▏     | 168/400 [00:01<00:01, 122.19it/s]
#
# Chain 0:  45%|████▌     | 181/400 [00:01<00:01, 122.26it/s]
#
# Chain 0:  48%|████▊     | 194/400 [00:01<00:01, 122.27it/s]
#
# Chain 0:  52%|█████▏    | 207/400 [00:01<00:01, 122.21it/s]
#
# Chain 0:  55%|█████▌    | 220/400 [00:01<00:01, 122.30it/s]
#
# Chain 0:  58%|█████▊    | 233/400 [00:01<00:01, 122.33it/s]
#
# Chain 0:  62%|██████▏   | 246/400 [00:02<00:01, 122.37it/s]
#
# Chain 0:  65%|██████▍   | 259/400 [00:02<00:01, 122.37it/s]
#
# Chain 0:  68%|██████▊   | 272/400 [00:02<00:01, 122.47it/s]
#
# Chain 0:  71%|███████▏  | 285/400 [00:02<00:00, 122.54it/s]
#
# Chain 0:  74%|███████▍  | 298/400 [00:02<00:00, 122.48it/s]
#
# Chain 0:  78%|███████▊  | 311/400 [00:02<00:00, 122.48it/s]
#
# Chain 0:  81%|████████  | 324/400 [00:02<00:00, 122.49it/s]
#
# Chain 0:  84%|████████▍ | 337/400 [00:02<00:00, 122.45it/s]
#
# Chain 0:  88%|████████▊ | 350/400 [00:02<00:00, 122.36it/s]
#
# Chain 0:  91%|█████████ | 363/400 [00:02<00:00, 122.39it/s]
#
# Chain 0:  94%|█████████▍| 376/400 [00:03<00:00, 122.43it/s]
#
# Chain 0: 100%|██████████| 400/400 [00:03<00:00, 121.98it/s]
#
#
# Chain 0:   0%|          | 0/400 [00:00<?, ?it/s]
#
# Chain 0:   3%|▎         | 12/400 [00:00<00:03, 116.32it/s]
#
# Chain 0:   6%|▋         | 25/400 [00:00<00:03, 120.04it/s]
#
# Chain 0:  10%|▉         | 38/400 [00:00<00:02, 121.13it/s]
#
# Chain 0:  13%|█▎        | 51/400 [00:00<00:02, 121.47it/s]
#
# Chain 0:  16%|█▌        | 64/400 [00:00<00:02, 121.85it/s]
#
# Chain 0:  19%|█▉        | 77/400 [00:00<00:02, 122.02it/s]
#
# Chain 0:  22%|██▎       | 90/400 [00:00<00:02, 122.13it/s]
#
# Chain 0:  26%|██▌       | 103/400 [00:00<00:02, 122.03it/s]
#
# Chain 0:  29%|██▉       | 116/400 [00:00<00:02, 122.08it/s]
#
# Chain 0:  32%|███▏      | 129/400 [00:01<00:02, 122.17it/s]
#
# Chain 0:  36%|███▌      | 142/400 [00:01<00:02, 122.23it/s]
#
# Chain 0:  39%|███▉      | 155/400 [00:01<00:02, 122.26it/s]
#
# Chain 0:  42%|████▏     | 168/400 [00:01<00:01, 122.22it/s]
#
# Chain 0:  45%|████▌     | 181/400 [00:01<00:01, 122.26it/s]
#
# Chain 0:  48%|████▊     | 194/400 [00:01<00:01, 122.30it/s]
#
# Chain 0:  52%|█████▏    | 207/400 [00:01<00:01, 122.33it/s]
#
# Chain 0:  55%|█████▌    | 220/400 [00:01<00:01, 122.42it/s]
#
# Chain 0:  58%|█████▊    | 233/400 [00:01<00:01, 122.47it/s]
#
# Chain 0:  62%|██████▏   | 246/400 [00:02<00:01, 122.52it/s]
#
# Chain 0:  65%|██████▍   | 259/400 [00:02<00:01, 122.61it/s]
#
# Chain 0:  68%|██████▊   | 272/400 [00:02<00:01, 122.59it/s]
#
# Chain 0:  71%|███████▏  | 285/400 [00:02<00:00, 122.43it/s]
#
# Chain 0:  74%|███████▍  | 298/400 [00:02<00:00, 122.44it/s]
#
# Chain 0:  78%|███████▊  | 311/400 [00:02<00:00, 122.48it/s]
#
# Chain 0:  81%|████████  | 324/400 [00:02<00:00, 122.51it/s]
#
# Chain 0:  84%|████████▍ | 337/400 [00:02<00:00, 122.53it/s]
#
# Chain 0:  88%|████████▊ | 350/400 [00:02<00:00, 122.53it/s]
#
# Chain 0:  91%|█████████ | 363/400 [00:02<00:00, 122.52it/s]
#
# Chain 0:  94%|█████████▍| 376/400 [00:03<00:00, 122.52it/s]
#
# Chain 0: 100%|██████████| 400/400 [00:03<00:00, 122.20it/s]
#
#
# Chain 0:   0%|          | 0/400 [00:00<?, ?it/s]
#
# Chain 0:   3%|▎         | 12/400 [00:00<00:03, 116.70it/s]
#
# Chain 0:   6%|▋         | 25/400 [00:00<00:03, 120.03it/s]
#
# Chain 0:  10%|▉         | 38/400 [00:00<00:02, 120.81it/s]
#
# Chain 0:  13%|█▎        | 51/400 [00:00<00:02, 121.18it/s]
#
# Chain 0:  16%|█▌        | 64/400 [00:00<00:02, 121.52it/s]
#
# Chain 0:  19%|█▉        | 77/400 [00:00<00:02, 121.71it/s]
#
# Chain 0:  22%|██▎       | 90/400 [00:00<00:02, 121.92it/s]
#
# Chain 0:  26%|██▌       | 103/400 [00:00<00:02, 122.02it/s]
#
# Chain 0:  29%|██▉       | 116/400 [00:00<00:02, 121.98it/s]
#
# Chain 0:  32%|███▏      | 129/400 [00:01<00:02, 122.10it/s]
#
# Chain 0:  36%|███▌      | 142/400 [00:01<00:02, 122.11it/s]
#
# Chain 0:  39%|███▉      | 155/400 [00:01<00:02, 122.13it/s]
#
# Chain 0:  42%|████▏     | 168/400 [00:01<00:01, 122.17it/s]
#
# Chain 0:  45%|████▌     | 181/400 [00:01<00:01, 122.24it/s]
#
# Chain 0:  48%|████▊     | 194/400 [00:01<00:01, 122.26it/s]
#
# Chain 0:  52%|█████▏    | 207/400 [00:01<00:01, 122.31it/s]
#
# Chain 0:  55%|█████▌    | 220/400 [00:01<00:01, 122.34it/s]
#
# Chain 0:  58%|█████▊    | 233/400 [00:01<00:01, 122.36it/s]
#
# Chain 0:  62%|██████▏   | 246/400 [00:02<00:01, 122.21it/s]
#
# Chain 0:  65%|██████▍   | 259/400 [00:02<00:01, 122.26it/s]
#
# Chain 0:  68%|██████▊   | 272/400 [00:02<00:01, 122.39it/s]
#
# Chain 0:  71%|███████▏  | 285/400 [00:02<00:00, 122.46it/s]
#
# Chain 0:  74%|███████▍  | 298/400 [00:02<00:00, 122.40it/s]
#
# Chain 0:  78%|███████▊  | 311/400 [00:02<00:00, 122.45it/s]
#
# Chain 0:  81%|████████  | 324/400 [00:02<00:00, 122.46it/s]
#
# Chain 0:  84%|████████▍ | 337/400 [00:02<00:00, 122.43it/s]
#
# Chain 0:  88%|████████▊ | 350/400 [00:02<00:00, 122.41it/s]
#
# Chain 0:  91%|█████████ | 363/400 [00:02<00:00, 122.36it/s]
#
# Chain 0:  94%|█████████▍| 376/400 [00:03<00:00, 122.32it/s]
#
# Chain 0: 100%|██████████| 400/400 [00:03<00:00, 122.08it/s]
#
#
# Chain 0:   0%|          | 0/400 [00:00<?, ?it/s]
#
# Chain 0:   3%|▎         | 12/400 [00:00<00:03, 115.63it/s]
#
# Chain 0:   6%|▋         | 25/400 [00:00<00:03, 119.45it/s]
#
# Chain 0:  10%|▉         | 38/400 [00:00<00:03, 120.60it/s]
#
# Chain 0:  13%|█▎        | 51/400 [00:00<00:02, 121.18it/s]
#
# Chain 0:  16%|█▌        | 64/400 [00:00<00:02, 121.56it/s]
#
# Chain 0:  19%|█▉        | 77/400 [00:00<00:02, 121.70it/s]
#
# Chain 0:  22%|██▎       | 90/400 [00:00<00:02, 121.98it/s]
#
# Chain 0:  26%|██▌       | 103/400 [00:00<00:02, 122.07it/s]
#
# Chain 0:  29%|██▉       | 116/400 [00:00<00:02, 122.19it/s]
#
# Chain 0:  32%|███▏      | 129/400 [00:01<00:02, 122.29it/s]
#
# Chain 0:  36%|███▌      | 142/400 [00:01<00:02, 122.28it/s]
#
# Chain 0:  39%|███▉      | 155/400 [00:01<00:02, 122.28it/s]
#
# Chain 0:  42%|████▏     | 168/400 [00:01<00:01, 122.33it/s]
#
# Chain 0:  45%|████▌     | 181/400 [00:01<00:01, 122.39it/s]
#
# Chain 0:  48%|████▊     | 194/400 [00:01<00:01, 122.42it/s]
#
# Chain 0:  52%|█████▏    | 207/400 [00:01<00:01, 122.43it/s]
#
# Chain 0:  55%|█████▌    | 220/400 [00:01<00:01, 122.49it/s]
#
# Chain 0:  58%|█████▊    | 233/400 [00:01<00:01, 122.43it/s]
#
# Chain 0:  62%|██████▏   | 246/400 [00:02<00:01, 122.47it/s]
#
# Chain 0:  65%|██████▍   | 259/400 [00:02<00:01, 122.41it/s]
#
# Chain 0:  68%|██████▊   | 272/400 [00:02<00:01, 122.44it/s]
#
# Chain 0:  71%|███████▏  | 285/400 [00:02<00:00, 122.48it/s]
#
# Chain 0:  74%|███████▍  | 298/400 [00:02<00:00, 122.48it/s]
#
# Chain 0:  78%|███████▊  | 311/400 [00:02<00:00, 122.49it/s]
#
# Chain 0:  81%|████████  | 324/400 [00:02<00:00, 122.54it/s]
#
# Chain 0:  84%|████████▍ | 337/400 [00:02<00:00, 122.49it/s]
#
# Chain 0:  88%|████████▊ | 350/400 [00:02<00:00, 122.39it/s]
#
# Chain 0:  91%|█████████ | 363/400 [00:02<00:00, 122.47it/s]
#
# Chain 0:  94%|█████████▍| 376/400 [00:03<00:00, 122.50it/s]
#
# Chain 0: 100%|██████████| 400/400 [00:03<00:00, 122.16it/s]
#
#
# Chain 0:   0%|          | 0/400 [00:00<?, ?it/s]
#
# Chain 0:   3%|▎         | 12/400 [00:00<00:03, 116.31it/s]
#
# Chain 0:   6%|▋         | 25/400 [00:00<00:03, 119.97it/s]
#
# Chain 0:  10%|▉         | 38/400 [00:00<00:02, 121.12it/s]
#
# Chain 0:  13%|█▎        | 51/400 [00:00<00:02, 121.72it/s]
#
# Chain 0:  16%|█▌        | 64/400 [00:00<00:02, 122.04it/s]
#
# Chain 0:  19%|█▉        | 77/400 [00:00<00:02, 122.21it/s]
#
# Chain 0:  22%|██▎       | 90/400 [00:00<00:02, 122.29it/s]
#
# Chain 0:  26%|██▌       | 103/400 [00:00<00:02, 122.36it/s]
#
# Chain 0:  29%|██▉       | 116/400 [00:00<00:02, 122.34it/s]
#
# Chain 0:  32%|███▏      | 129/400 [00:01<00:02, 122.39it/s]
#
# Chain 0:  36%|███▌      | 142/400 [00:01<00:02, 122.48it/s]
#
# Chain 0:  39%|███▉      | 155/400 [00:01<00:02, 122.46it/s]
#
# Chain 0:  42%|████▏     | 168/400 [00:01<00:01, 122.50it/s]
#
# Chain 0:  45%|████▌     | 181/400 [00:01<00:01, 122.52it/s]
#
# Chain 0:  48%|████▊     | 194/400 [00:01<00:01, 122.47it/s]
#
# Chain 0:  52%|█████▏    | 207/400 [00:01<00:01, 122.49it/s]
#
# Chain 0:  55%|█████▌    | 220/400 [00:01<00:01, 122.51it/s]
#
# Chain 0:  58%|█████▊    | 233/400 [00:01<00:01, 122.43it/s]
#
# Chain 0:  62%|██████▏   | 246/400 [00:02<00:01, 122.45it/s]
#
# Chain 0:  65%|██████▍   | 259/400 [00:02<00:01, 122.49it/s]
#
# Chain 0:  68%|██████▊   | 272/400 [00:02<00:01, 122.52it/s]
#
# Chain 0:  71%|███████▏  | 285/400 [00:02<00:00, 122.55it/s]
#
# Chain 0:  74%|███████▍  | 298/400 [00:02<00:00, 122.49it/s]
#
# Chain 0:  78%|███████▊  | 311/400 [00:02<00:00, 122.51it/s]
#
# Chain 0:  81%|████████  | 324/400 [00:02<00:00, 122.50it/s]
#
# Chain 0:  84%|████████▍ | 337/400 [00:02<00:00, 122.44it/s]
#
# Chain 0:  88%|████████▊ | 350/400 [00:02<00:00, 122.46it/s]
#
# Chain 0:  91%|█████████ | 363/400 [00:02<00:00, 122.49it/s]
#
# Chain 0:  94%|█████████▍| 376/400 [00:03<00:00, 122.40it/s]
#
# Chain 0: 100%|██████████| 400/400 [00:03<00:00, 122.29it/s]
#
#
# Chain 0:   0%|          | 0/400 [00:00<?, ?it/s]
#
# Chain 0:   3%|▎         | 12/400 [00:00<00:03, 116.41it/s]
#
# Chain 0:   6%|▋         | 25/400 [00:00<00:03, 120.17it/s]
#
# Chain 0:  10%|▉         | 38/400 [00:00<00:02, 121.29it/s]
#
# Chain 0:  13%|█▎        | 51/400 [00:00<00:02, 121.57it/s]
#
# Chain 0:  16%|█▌        | 64/400 [00:00<00:02, 121.91it/s]
#
# Chain 0:  19%|█▉        | 77/400 [00:00<00:02, 122.13it/s]
#
# Chain 0:  22%|██▎       | 90/400 [00:00<00:02, 122.20it/s]
#
# Chain 0:  26%|██▌       | 103/400 [00:00<00:02, 122.28it/s]
#
# Chain 0:  29%|██▉       | 116/400 [00:00<00:02, 122.37it/s]
#
# Chain 0:  32%|███▏      | 129/400 [00:01<00:02, 122.38it/s]
#
# Chain 0:  36%|███▌      | 142/400 [00:01<00:02, 122.36it/s]
#
# Chain 0:  39%|███▉      | 155/400 [00:01<00:02, 122.37it/s]
#
# Chain 0:  42%|████▏     | 168/400 [00:01<00:01, 122.39it/s]
#
# Chain 0:  45%|████▌     | 181/400 [00:01<00:01, 122.39it/s]
#
# Chain 0:  48%|████▊     | 194/400 [00:01<00:01, 122.45it/s]
#
# Chain 0:  52%|█████▏    | 207/400 [00:01<00:01, 122.50it/s]
#
# Chain 0:  55%|█████▌    | 220/400 [00:01<00:01, 122.57it/s]
#
# Chain 0:  58%|█████▊    | 233/400 [00:01<00:01, 122.56it/s]
#
# Chain 0:  62%|██████▏   | 246/400 [00:02<00:01, 122.62it/s]
#
# Chain 0:  65%|██████▍   | 259/400 [00:02<00:01, 122.63it/s]
#
# Chain 0:  68%|██████▊   | 272/400 [00:02<00:01, 122.65it/s]
#
# Chain 0:  71%|███████▏  | 285/400 [00:02<00:00, 122.61it/s]
#
# Chain 0:  74%|███████▍  | 298/400 [00:02<00:00, 122.56it/s]
#
# Chain 0:  78%|███████▊  | 311/400 [00:02<00:00, 122.58it/s]
#
# Chain 0:  81%|████████  | 324/400 [00:02<00:00, 122.59it/s]
#
# Chain 0:  84%|████████▍ | 337/400 [00:02<00:00, 122.59it/s]
#
# Chain 0:  88%|████████▊ | 350/400 [00:02<00:00, 122.65it/s]
#
# Chain 0:  91%|█████████ | 363/400 [00:02<00:00, 122.67it/s]
#
# Chain 0:  94%|█████████▍| 376/400 [00:03<00:00, 122.68it/s]
#
# Chain 0: 100%|██████████| 400/400 [00:03<00:00, 122.35it/s]
#
#
# Chain 0:   0%|          | 0/400 [00:00<?, ?it/s]
#
# Chain 0:   3%|▎         | 12/400 [00:00<00:03, 116.54it/s]
#
# Chain 0:   6%|▋         | 25/400 [00:00<00:03, 120.27it/s]
#
# Chain 0:  10%|▉         | 38/400 [00:00<00:02, 121.36it/s]
#
# Chain 0:  13%|█▎        | 51/400 [00:00<00:02, 121.79it/s]
#
# Chain 0:  16%|█▌        | 64/400 [00:00<00:02, 122.13it/s]
#
# Chain 0:  19%|█▉        | 77/400 [00:00<00:02, 122.29it/s]
#
# Chain 0:  22%|██▎       | 90/400 [00:00<00:02, 122.35it/s]
#
# Chain 0:  26%|██▌       | 103/400 [00:00<00:02, 122.40it/s]
#
# Chain 0:  29%|██▉       | 116/400 [00:00<00:02, 122.30it/s]
#
# Chain 0:  32%|███▏      | 129/400 [00:01<00:02, 122.41it/s]
#
# Chain 0:  36%|███▌      | 142/400 [00:01<00:02, 122.41it/s]
#
# Chain 0:  39%|███▉      | 155/400 [00:01<00:01, 122.51it/s]
#
# Chain 0:  42%|████▏     | 168/400 [00:01<00:01, 122.57it/s]
#
# Chain 0:  45%|████▌     | 181/400 [00:01<00:01, 122.55it/s]
#
# Chain 0:  48%|████▊     | 194/400 [00:01<00:01, 122.59it/s]
#
# Chain 0:  52%|█████▏    | 207/400 [00:01<00:01, 122.52it/s]
#
# Chain 0:  55%|█████▌    | 220/400 [00:01<00:01, 122.53it/s]
#
# Chain 0:  58%|█████▊    | 233/400 [00:01<00:01, 122.56it/s]
#
# Chain 0:  62%|██████▏   | 246/400 [00:02<00:01, 122.53it/s]
#
# Chain 0:  65%|██████▍   | 259/400 [00:02<00:01, 122.45it/s]
#
# Chain 0:  68%|██████▊   | 272/400 [00:02<00:01, 122.43it/s]
#
# Chain 0:  71%|███████▏  | 285/400 [00:02<00:00, 122.55it/s]
#
# Chain 0:  74%|███████▍  | 298/400 [00:02<00:00, 122.60it/s]
#
# Chain 0:  78%|███████▊  | 311/400 [00:02<00:00, 122.58it/s]
#
# Chain 0:  81%|████████  | 324/400 [00:02<00:00, 122.61it/s]
#
# Chain 0:  84%|████████▍ | 337/400 [00:02<00:00, 122.50it/s]
#
# Chain 0:  88%|████████▊ | 350/400 [00:02<00:00, 122.47it/s]
#
# Chain 0:  91%|█████████ | 363/400 [00:02<00:00, 122.57it/s]
#
# Chain 0:  94%|█████████▍| 376/400 [00:03<00:00, 122.56it/s]
#
# Chain 0: 100%|██████████| 400/400 [00:03<00:00, 122.36it/s]
#
#
# Chain 0:   0%|          | 0/400 [00:00<?, ?it/s]
#
# Chain 0:   3%|▎         | 12/400 [00:00<00:03, 116.38it/s]
#
# Chain 0:   6%|▋         | 25/400 [00:00<00:03, 120.08it/s]
#
# Chain 0:  10%|▉         | 38/400 [00:00<00:02, 121.08it/s]
#
# Chain 0:  13%|█▎        | 51/400 [00:00<00:02, 121.59it/s]
#
# Chain 0:  16%|█▌        | 64/400 [00:00<00:02, 121.75it/s]
#
# Chain 0:  19%|█▉        | 77/400 [00:00<00:02, 121.88it/s]
#
# Chain 0:  22%|██▎       | 90/400 [00:00<00:02, 121.95it/s]
#
# Chain 0:  26%|██▌       | 103/400 [00:00<00:02, 122.03it/s]
#
# Chain 0:  29%|██▉       | 116/400 [00:00<00:02, 122.18it/s]
#
# Chain 0:  32%|███▏      | 129/400 [00:01<00:02, 122.20it/s]
#
# Chain 0:  36%|███▌      | 142/400 [00:01<00:02, 122.23it/s]
#
# Chain 0:  39%|███▉      | 155/400 [00:01<00:02, 122.26it/s]
#
# Chain 0:  42%|████▏     | 168/400 [00:01<00:01, 122.33it/s]
#
# Chain 0:  45%|████▌     | 181/400 [00:01<00:01, 122.42it/s]
#
# Chain 0:  48%|████▊     | 194/400 [00:01<00:01, 122.31it/s]
#
# Chain 0:  52%|█████▏    | 207/400 [00:01<00:01, 122.39it/s]
#
# Chain 0:  55%|█████▌    | 220/400 [00:01<00:01, 122.33it/s]
#
# Chain 0:  58%|█████▊    | 233/400 [00:01<00:01, 122.36it/s]
#
# Chain 0:  62%|██████▏   | 246/400 [00:02<00:01, 122.44it/s]
#
# Chain 0:  65%|██████▍   | 259/400 [00:02<00:01, 122.56it/s]
#
# Chain 0:  68%|██████▊   | 272/400 [00:02<00:01, 122.49it/s]
#
# Chain 0:  71%|███████▏  | 285/400 [00:02<00:00, 122.51it/s]
#
# Chain 0:  74%|███████▍  | 298/400 [00:02<00:00, 122.48it/s]
#
# Chain 0:  78%|███████▊  | 311/400 [00:02<00:00, 122.50it/s]
#
# Chain 0:  81%|████████  | 324/400 [00:02<00:00, 122.57it/s]
#
# Chain 0:  84%|████████▍ | 337/400 [00:02<00:00, 122.47it/s]
#
# Chain 0:  88%|████████▊ | 350/400 [00:02<00:00, 122.50it/s]
#
# Chain 0:  91%|█████████ | 363/400 [00:02<00:00, 122.49it/s]
#
# Chain 0:  94%|█████████▍| 376/400 [00:03<00:00, 122.46it/s]
#
# Chain 0: 100%|██████████| 400/400 [00:03<00:00, 122.21it/s]
#
#
# Chain 0:   0%|          | 0/400 [00:00<?, ?it/s]
#
# Chain 0:   3%|▎         | 12/400 [00:00<00:03, 116.09it/s]
#
# Chain 0:   6%|▋         | 25/400 [00:00<00:03, 119.91it/s]
#
# Chain 0:  10%|▉         | 38/400 [00:00<00:02, 120.97it/s]
#
# Chain 0:  13%|█▎        | 51/400 [00:00<00:02, 121.63it/s]
#
# Chain 0:  16%|█▌        | 64/400 [00:00<00:02, 121.88it/s]
#
# Chain 0:  19%|█▉        | 77/400 [00:00<00:02, 122.11it/s]
#
# Chain 0:  22%|██▎       | 90/400 [00:00<00:02, 122.22it/s]
#
# Chain 0:  26%|██▌       | 103/400 [00:00<00:02, 122.41it/s]
#
# Chain 0:  29%|██▉       | 116/400 [00:00<00:02, 122.54it/s]
#
# Chain 0:  32%|███▏      | 129/400 [00:01<00:02, 122.55it/s]
#
# Chain 0:  36%|███▌      | 142/400 [00:01<00:02, 122.54it/s]
#
# Chain 0:  39%|███▉      | 155/400 [00:01<00:01, 122.59it/s]
#
# Chain 0:  42%|████▏     | 168/400 [00:01<00:01, 122.48it/s]
#
# Chain 0:  45%|████▌     | 181/400 [00:01<00:01, 122.46it/s]
#
# Chain 0:  48%|████▊     | 194/400 [00:01<00:01, 122.46it/s]
#
# Chain 0:  52%|█████▏    | 207/400 [00:01<00:01, 122.42it/s]
#
# Chain 0:  55%|█████▌    | 220/400 [00:01<00:01, 122.40it/s]
#
# Chain 0:  58%|█████▊    | 233/400 [00:01<00:01, 122.45it/s]
#
# Chain 0:  62%|██████▏   | 246/400 [00:02<00:01, 122.42it/s]
#
# Chain 0:  65%|██████▍   | 259/400 [00:02<00:01, 122.47it/s]
#
# Chain 0:  68%|██████▊   | 272/400 [00:02<00:01, 122.53it/s]
#
# Chain 0:  71%|███████▏  | 285/400 [00:02<00:00, 122.53it/s]
#
# Chain 0:  74%|███████▍  | 298/400 [00:02<00:00, 122.59it/s]
#
# Chain 0:  78%|███████▊  | 311/400 [00:02<00:00, 122.57it/s]
#
# Chain 0:  81%|████████  | 324/400 [00:02<00:00, 122.50it/s]
#
# Chain 0:  84%|████████▍ | 337/400 [00:02<00:00, 122.57it/s]
#
# Chain 0:  88%|████████▊ | 350/400 [00:02<00:00, 122.61it/s]
#
# Chain 0:  91%|█████████ | 363/400 [00:02<00:00, 122.54it/s]
#
# Chain 0:  94%|█████████▍| 376/400 [00:03<00:00, 122.63it/s]
#
# Chain 0: 100%|██████████| 400/400 [00:03<00:00, 122.32it/s]
#
#
# Chain 0:   0%|          | 0/400 [00:00<?, ?it/s]
#
# Chain 0:   3%|▎         | 12/400 [00:00<00:03, 116.37it/s]
#
# Chain 0:   6%|▋         | 25/400 [00:00<00:03, 120.10it/s]
#
# Chain 0:  10%|▉         | 38/400 [00:00<00:02, 120.80it/s]
#
# Chain 0:  13%|█▎        | 51/400 [00:00<00:02, 121.23it/s]
#
# Chain 0:  16%|█▌        | 64/400 [00:00<00:02, 121.59it/s]
#
# Chain 0:  19%|█▉        | 77/400 [00:00<00:02, 121.79it/s]
#
# Chain 0:  22%|██▎       | 90/400 [00:00<00:02, 121.93it/s]
#
# Chain 0:  26%|██▌       | 103/400 [00:00<00:02, 122.09it/s]
#
# Chain 0:  29%|██▉       | 116/400 [00:00<00:02, 122.16it/s]
#
# Chain 0:  32%|███▏      | 129/400 [00:01<00:02, 122.17it/s]
#
# Chain 0:  36%|███▌      | 142/400 [00:01<00:02, 122.15it/s]
#
# Chain 0:  39%|███▉      | 155/400 [00:01<00:02, 122.16it/s]
#
# Chain 0:  42%|████▏     | 168/400 [00:01<00:01, 122.14it/s]
#
# Chain 0:  45%|████▌     | 181/400 [00:01<00:01, 122.14it/s]
#
# Chain 0:  48%|████▊     | 194/400 [00:01<00:01, 122.16it/s]
#
# Chain 0:  52%|█████▏    | 207/400 [00:01<00:01, 122.26it/s]
#
# Chain 0:  55%|█████▌    | 220/400 [00:01<00:01, 122.45it/s]
#
# Chain 0:  58%|█████▊    | 233/400 [00:01<00:01, 122.33it/s]
#
# Chain 0:  62%|██████▏   | 246/400 [00:02<00:01, 122.35it/s]
#
# Chain 0:  65%|██████▍   | 259/400 [00:02<00:01, 122.41it/s]
#
# Chain 0:  68%|██████▊   | 272/400 [00:02<00:01, 122.39it/s]
#
# Chain 0:  71%|███████▏  | 285/400 [00:02<00:00, 122.41it/s]
#
# Chain 0:  74%|███████▍  | 298/400 [00:02<00:00, 122.44it/s]
#
# Chain 0:  78%|███████▊  | 311/400 [00:02<00:00, 122.42it/s]
#
# Chain 0:  81%|████████  | 324/400 [00:02<00:00, 122.45it/s]
#
# Chain 0:  84%|████████▍ | 337/400 [00:02<00:00, 122.44it/s]
#
# Chain 0:  88%|████████▊ | 350/400 [00:02<00:00, 122.46it/s]
#
# Chain 0:  91%|█████████ | 363/400 [00:02<00:00, 122.51it/s]
#
# Chain 0:  94%|█████████▍| 376/400 [00:03<00:00, 122.53it/s]
#
# Chain 0: 100%|██████████| 400/400 [00:03<00:00, 122.15it/s]
#
#
# Chain 0:   0%|          | 0/400 [00:00<?, ?it/s]
#
# Chain 0:   3%|▎         | 12/400 [00:00<00:03, 116.11it/s]
#
# Chain 0:   6%|▋         | 25/400 [00:00<00:03, 119.95it/s]
#
# Chain 0:  10%|▉         | 38/400 [00:00<00:02, 121.10it/s]
#
# Chain 0:  13%|█▎        | 51/400 [00:00<00:02, 121.72it/s]
#
# Chain 0:  16%|█▌        | 64/400 [00:00<00:02, 122.06it/s]
#
# Chain 0:  19%|█▉        | 77/400 [00:00<00:02, 122.29it/s]
#
# Chain 0:  22%|██▎       | 90/400 [00:00<00:02, 122.37it/s]
#
# Chain 0:  26%|██▌       | 103/400 [00:00<00:02, 122.38it/s]
#
# Chain 0:  29%|██▉       | 116/400 [00:00<00:02, 122.43it/s]
#
# Chain 0:  32%|███▏      | 129/400 [00:01<00:02, 122.58it/s]
#
# Chain 0:  36%|███▌      | 142/400 [00:01<00:02, 122.50it/s]
#
# Chain 0:  39%|███▉      | 155/400 [00:01<00:01, 122.57it/s]
#
# Chain 0:  42%|████▏     | 168/400 [00:01<00:01, 122.55it/s]
#
# Chain 0:  45%|████▌     | 181/400 [00:01<00:01, 122.59it/s]
#
# Chain 0:  48%|████▊     | 194/400 [00:01<00:01, 122.52it/s]
#
# Chain 0:  52%|█████▏    | 207/400 [00:01<00:01, 122.50it/s]
#
# Chain 0:  55%|█████▌    | 220/400 [00:01<00:01, 122.60it/s]
#
# Chain 0:  58%|█████▊    | 233/400 [00:01<00:01, 122.64it/s]
#
# Chain 0:  62%|██████▏   | 246/400 [00:02<00:01, 122.63it/s]
#
# Chain 0:  65%|██████▍   | 259/400 [00:02<00:01, 122.66it/s]
#
# Chain 0:  68%|██████▊   | 272/400 [00:02<00:01, 122.66it/s]
#
# Chain 0:  71%|███████▏  | 285/400 [00:02<00:00, 122.72it/s]
#
# Chain 0:  74%|███████▍  | 298/400 [00:02<00:00, 122.65it/s]
#
# Chain 0:  78%|███████▊  | 311/400 [00:02<00:00, 122.69it/s]
#
# Chain 0:  81%|████████  | 324/400 [00:02<00:00, 122.58it/s]
#
# Chain 0:  84%|████████▍ | 337/400 [00:02<00:00, 122.56it/s]
#
# Chain 0:  88%|████████▊ | 350/400 [00:02<00:00, 122.55it/s]
#
# Chain 0:  91%|█████████ | 363/400 [00:02<00:00, 122.63it/s]
#
# Chain 0:  94%|█████████▍| 376/400 [00:03<00:00, 122.61it/s]
#
# Chain 0: 100%|██████████| 400/400 [00:03<00:00, 122.39it/s]
#
#
# Chain 0:   0%|          | 0/400 [00:00<?, ?it/s]
#
# Chain 0:   3%|▎         | 12/400 [00:00<00:03, 116.58it/s]
#
# Chain 0:   6%|▋         | 25/400 [00:00<00:03, 120.13it/s]
#
# Chain 0:  10%|▉         | 38/400 [00:00<00:02, 121.22it/s]
#
# Chain 0:  13%|█▎        | 51/400 [00:00<00:02, 121.78it/s]
#
# Chain 0:  16%|█▌        | 64/400 [00:00<00:02, 122.03it/s]
#
# Chain 0:  19%|█▉        | 77/400 [00:00<00:02, 122.24it/s]
#
# Chain 0:  22%|██▎       | 90/400 [00:00<00:02, 122.40it/s]
#
# Chain 0:  26%|██▌       | 103/400 [00:00<00:02, 122.51it/s]
#
# Chain 0:  29%|██▉       | 116/400 [00:00<00:02, 122.50it/s]
#
# Chain 0:  32%|███▏      | 129/400 [00:01<00:02, 122.52it/s]
#
# Chain 0:  36%|███▌      | 142/400 [00:01<00:02, 122.54it/s]
#
# Chain 0:  39%|███▉      | 155/400 [00:01<00:01, 122.51it/s]
#
# Chain 0:  42%|████▏     | 168/400 [00:01<00:01, 122.49it/s]
#
# Chain 0:  45%|████▌     | 181/400 [00:01<00:01, 122.59it/s]
#
# Chain 0:  48%|████▊     | 194/400 [00:01<00:01, 122.60it/s]
#
# Chain 0:  52%|█████▏    | 207/400 [00:01<00:01, 122.60it/s]
#
# Chain 0:  55%|█████▌    | 220/400 [00:01<00:01, 122.60it/s]
#
# Chain 0:  58%|█████▊    | 233/400 [00:01<00:01, 122.57it/s]
#
# Chain 0:  62%|██████▏   | 246/400 [00:02<00:01, 122.59it/s]
#
# Chain 0:  65%|██████▍   | 259/400 [00:02<00:01, 122.53it/s]
#
# Chain 0:  68%|██████▊   | 272/400 [00:02<00:01, 122.59it/s]
#
# Chain 0:  71%|███████▏  | 285/400 [00:02<00:00, 122.61it/s]
#
# Chain 0:  74%|███████▍  | 298/400 [00:02<00:00, 122.52it/s]
#
# Chain 0:  78%|███████▊  | 311/400 [00:02<00:00, 122.43it/s]
#
# Chain 0:  81%|████████  | 324/400 [00:02<00:00, 122.33it/s]
#
# Chain 0:  84%|████████▍ | 337/400 [00:02<00:00, 122.26it/s]
#
# Chain 0:  88%|████████▊ | 350/400 [00:02<00:00, 122.23it/s]
#
# Chain 0:  91%|█████████ | 363/400 [00:02<00:00, 122.14it/s]
#
# Chain 0:  94%|█████████▍| 376/400 [00:03<00:00, 121.99it/s]
#
# Chain 0: 100%|██████████| 400/400 [00:03<00:00, 122.22it/s]
#
#
# Chain 0:   0%|          | 0/400 [00:00<?, ?it/s]
#
# Chain 0:   3%|▎         | 12/400 [00:00<00:03, 115.80it/s]
#
# Chain 0:   6%|▋         | 25/400 [00:00<00:03, 119.51it/s]
#
# Chain 0:  10%|▉         | 38/400 [00:00<00:03, 120.65it/s]
#
# Chain 0:  13%|█▎        | 51/400 [00:00<00:02, 121.29it/s]
#
# Chain 0:  16%|█▌        | 64/400 [00:00<00:02, 121.61it/s]
#
# Chain 0:  19%|█▉        | 77/400 [00:00<00:02, 121.82it/s]
#
# Chain 0:  22%|██▎       | 90/400 [00:00<00:02, 121.90it/s]
#
# Chain 0:  26%|██▌       | 103/400 [00:00<00:02, 122.03it/s]
#
# Chain 0:  29%|██▉       | 116/400 [00:00<00:02, 122.13it/s]
#
# Chain 0:  32%|███▏      | 129/400 [00:01<00:02, 122.08it/s]
#
# Chain 0:  36%|███▌      | 142/400 [00:01<00:02, 122.14it/s]
#
# Chain 0:  39%|███▉      | 155/400 [00:01<00:02, 122.11it/s]
#
# Chain 0:  42%|████▏     | 168/400 [00:01<00:01, 120.39it/s]
#
# Chain 0:  45%|████▌     | 181/400 [00:01<00:01, 119.48it/s]
#
# Chain 0:  48%|████▊     | 193/400 [00:01<00:01, 119.21it/s]
#
# Chain 0:  51%|█████▏    | 205/400 [00:01<00:01, 119.17it/s]
#
# Chain 0:  54%|█████▍    | 217/400 [00:01<00:01, 119.16it/s]
#
# Chain 0:  57%|█████▋    | 229/400 [00:01<00:01, 119.26it/s]
#
# Chain 0:  60%|██████    | 241/400 [00:02<00:01, 119.45it/s]
#
# Chain 0:  64%|██████▎   | 254/400 [00:02<00:01, 119.79it/s]
#
# Chain 0:  67%|██████▋   | 267/400 [00:02<00:01, 119.99it/s]
#
# Chain 0:  70%|███████   | 280/400 [00:02<00:00, 120.34it/s]
#
# Chain 0:  73%|███████▎  | 293/400 [00:02<00:00, 120.68it/s]
#
# Chain 0:  76%|███████▋  | 306/400 [00:02<00:00, 120.97it/s]
#
# Chain 0:  80%|███████▉  | 319/400 [00:02<00:00, 121.19it/s]
#
# Chain 0:  83%|████████▎ | 332/400 [00:02<00:00, 121.49it/s]
#
# Chain 0:  86%|████████▋ | 345/400 [00:02<00:00, 121.76it/s]
#
# Chain 0:  90%|████████▉ | 358/400 [00:02<00:00, 121.88it/s]
#
# Chain 0:  93%|█████████▎| 371/400 [00:03<00:00, 122.03it/s]
#
# Chain 0:  96%|█████████▌| 384/400 [00:03<00:00, 122.12it/s]
#
# Chain 0: 100%|██████████| 400/400 [00:03<00:00, 120.96it/s]
#
#
# Chain 0:   0%|          | 0/400 [00:00<?, ?it/s]
#
# Chain 0:   3%|▎         | 12/400 [00:00<00:03, 116.16it/s]
#
# Chain 0:   6%|▋         | 25/400 [00:00<00:03, 119.84it/s]
#
# Chain 0:  10%|▉         | 38/400 [00:00<00:02, 120.96it/s]
#
# Chain 0:  13%|█▎        | 51/400 [00:00<00:02, 121.57it/s]
#
# Chain 0:  16%|█▌        | 64/400 [00:00<00:02, 121.87it/s]
#
# Chain 0:  19%|█▉        | 77/400 [00:00<00:02, 122.00it/s]
#
# Chain 0:  22%|██▎       | 90/400 [00:00<00:02, 122.03it/s]
#
# Chain 0:  26%|██▌       | 103/400 [00:00<00:02, 122.12it/s]
#
# Chain 0:  29%|██▉       | 116/400 [00:00<00:02, 122.17it/s]
#
# Chain 0:  32%|███▏      | 129/400 [00:01<00:02, 122.15it/s]
#
# Chain 0:  36%|███▌      | 142/400 [00:01<00:02, 122.29it/s]
#
# Chain 0:  39%|███▉      | 155/400 [00:01<00:02, 122.24it/s]
#
# Chain 0:  42%|████▏     | 168/400 [00:01<00:01, 122.32it/s]
#
# Chain 0:  45%|████▌     | 181/400 [00:01<00:01, 122.36it/s]
#
# Chain 0:  48%|████▊     | 194/400 [00:01<00:01, 122.32it/s]
#
# Chain 0:  52%|█████▏    | 207/400 [00:01<00:01, 122.34it/s]
#
# Chain 0:  55%|█████▌    | 220/400 [00:01<00:01, 122.36it/s]
#
# Chain 0:  58%|█████▊    | 233/400 [00:01<00:01, 122.38it/s]
#
# Chain 0:  62%|██████▏   | 246/400 [00:02<00:01, 122.43it/s]
#
# Chain 0:  65%|██████▍   | 259/400 [00:02<00:01, 122.42it/s]
#
# Chain 0:  68%|██████▊   | 272/400 [00:02<00:01, 122.29it/s]
#
# Chain 0:  71%|███████▏  | 285/400 [00:02<00:00, 122.29it/s]
#
# Chain 0:  74%|███████▍  | 298/400 [00:02<00:00, 122.36it/s]
#
# Chain 0:  78%|███████▊  | 311/400 [00:02<00:00, 122.38it/s]
#
# Chain 0:  81%|████████  | 324/400 [00:02<00:00, 122.36it/s]
#
# Chain 0:  84%|████████▍ | 337/400 [00:02<00:00, 122.27it/s]
#
# Chain 0:  88%|████████▊ | 350/400 [00:02<00:00, 122.32it/s]
#
# Chain 0:  91%|█████████ | 363/400 [00:02<00:00, 122.36it/s]
#
# Chain 0:  94%|█████████▍| 376/400 [00:03<00:00, 122.33it/s]
#
# Chain 0: 100%|██████████| 400/400 [00:03<00:00, 122.12it/s]
#
#
# Chain 0:   0%|          | 0/400 [00:00<?, ?it/s]
#
# Chain 0:   3%|▎         | 12/400 [00:00<00:03, 116.33it/s]
#
# Chain 0:   6%|▋         | 25/400 [00:00<00:03, 119.95it/s]
#
# Chain 0:  10%|▉         | 38/400 [00:00<00:02, 121.02it/s]
#
# Chain 0:  13%|█▎        | 51/400 [00:00<00:02, 121.52it/s]
#
# Chain 0:  16%|█▌        | 64/400 [00:00<00:02, 121.80it/s]
#
# Chain 0:  19%|█▉        | 77/400 [00:00<00:02, 121.87it/s]
#
# Chain 0:  22%|██▎       | 90/400 [00:00<00:02, 121.99it/s]
#
# Chain 0:  26%|██▌       | 103/400 [00:00<00:02, 122.06it/s]
#
# Chain 0:  29%|██▉       | 116/400 [00:00<00:02, 122.14it/s]
#
# Chain 0:  32%|███▏      | 129/400 [00:01<00:02, 122.15it/s]
#
# Chain 0:  36%|███▌      | 142/400 [00:01<00:02, 122.15it/s]
#
# Chain 0:  39%|███▉      | 155/400 [00:01<00:02, 122.23it/s]
#
# Chain 0:  42%|████▏     | 168/400 [00:01<00:01, 122.24it/s]
#
# Chain 0:  45%|████▌     | 181/400 [00:01<00:01, 122.26it/s]
#
# Chain 0:  48%|████▊     | 194/400 [00:01<00:01, 122.26it/s]
#
# Chain 0:  52%|█████▏    | 207/400 [00:01<00:01, 122.26it/s]
#
# Chain 0:  55%|█████▌    | 220/400 [00:01<00:01, 122.29it/s]
#
# Chain 0:  58%|█████▊    | 233/400 [00:01<00:01, 122.25it/s]
#
# Chain 0:  62%|██████▏   | 246/400 [00:02<00:01, 122.15it/s]
#
# Chain 0:  65%|██████▍   | 259/400 [00:02<00:01, 122.19it/s]
#
# Chain 0:  68%|██████▊   | 272/400 [00:02<00:01, 122.15it/s]
#
# Chain 0:  71%|███████▏  | 285/400 [00:02<00:00, 122.22it/s]
#
# Chain 0:  74%|███████▍  | 298/400 [00:02<00:00, 122.31it/s]
#
# Chain 0:  78%|███████▊  | 311/400 [00:02<00:00, 122.26it/s]
#
# Chain 0:  81%|████████  | 324/400 [00:02<00:00, 122.28it/s]
#
# Chain 0:  84%|████████▍ | 337/400 [00:02<00:00, 122.28it/s]
#
# Chain 0:  88%|████████▊ | 350/400 [00:02<00:00, 122.36it/s]
#
# Chain 0:  91%|█████████ | 363/400 [00:02<00:00, 122.31it/s]
#
# Chain 0:  94%|█████████▍| 376/400 [00:03<00:00, 122.32it/s]
#
# Chain 0: 100%|██████████| 400/400 [00:03<00:00, 122.08it/s]
#
#
# Chain 0:   0%|          | 0/400 [00:00<?, ?it/s]
#
# Chain 0:   3%|▎         | 12/400 [00:00<00:03, 116.17it/s]
#
# Chain 0:   6%|▋         | 25/400 [00:00<00:03, 119.86it/s]
#
# Chain 0:  10%|▉         | 38/400 [00:00<00:02, 120.98it/s]
#
# Chain 0:  13%|█▎        | 51/400 [00:00<00:02, 121.59it/s]
#
# Chain 0:  16%|█▌        | 64/400 [00:00<00:02, 121.78it/s]
#
# Chain 0:  19%|█▉        | 77/400 [00:00<00:02, 121.77it/s]
#
# Chain 0:  22%|██▎       | 90/400 [00:00<00:02, 121.93it/s]
#
# Chain 0:  26%|██▌       | 103/400 [00:00<00:02, 122.09it/s]
#
# Chain 0:  29%|██▉       | 116/400 [00:00<00:02, 122.12it/s]
#
# Chain 0:  32%|███▏      | 129/400 [00:01<00:02, 122.13it/s]
#
# Chain 0:  36%|███▌      | 142/400 [00:01<00:02, 122.17it/s]
#
# Chain 0:  39%|███▉      | 155/400 [00:01<00:02, 122.20it/s]
#
# Chain 0:  42%|████▏     | 168/400 [00:01<00:01, 122.26it/s]
#
# Chain 0:  45%|████▌     | 181/400 [00:01<00:01, 122.26it/s]
#
# Chain 0:  48%|████▊     | 194/400 [00:01<00:01, 122.27it/s]
#
# Chain 0:  52%|█████▏    | 207/400 [00:01<00:01, 122.34it/s]
#
# Chain 0:  55%|█████▌    | 220/400 [00:01<00:01, 122.37it/s]
#
# Chain 0:  58%|█████▊    | 233/400 [00:01<00:01, 122.37it/s]
#
# Chain 0:  62%|██████▏   | 246/400 [00:02<00:01, 122.39it/s]
#
# Chain 0:  65%|██████▍   | 259/400 [00:02<00:01, 122.17it/s]
#
# Chain 0:  68%|██████▊   | 272/400 [00:02<00:01, 122.24it/s]
#
# Chain 0:  71%|███████▏  | 285/400 [00:02<00:00, 122.30it/s]
#
# Chain 0:  74%|███████▍  | 298/400 [00:02<00:00, 122.31it/s]
#
# Chain 0:  78%|███████▊  | 311/400 [00:02<00:00, 122.34it/s]
#
# Chain 0:  81%|████████  | 324/400 [00:02<00:00, 122.23it/s]
#
# Chain 0:  84%|████████▍ | 337/400 [00:02<00:00, 122.27it/s]
#
# Chain 0:  88%|████████▊ | 350/400 [00:02<00:00, 122.25it/s]
#
# Chain 0:  91%|█████████ | 363/400 [00:02<00:00, 122.26it/s]
#
# Chain 0:  94%|█████████▍| 376/400 [00:03<00:00, 122.25it/s]
#
# Chain 0: 100%|██████████| 400/400 [00:03<00:00, 122.07it/s]
#
#
# Chain 0:   0%|          | 0/400 [00:00<?, ?it/s]
#
# Chain 0:   3%|▎         | 12/400 [00:00<00:03, 116.07it/s]
#
# Chain 0:   6%|▋         | 25/400 [00:00<00:03, 119.78it/s]
#
# Chain 0:  10%|▉         | 38/400 [00:00<00:02, 121.00it/s]
#
# Chain 0:  13%|█▎        | 51/400 [00:00<00:02, 121.51it/s]
#
# Chain 0:  16%|█▌        | 64/400 [00:00<00:02, 121.84it/s]
#
# Chain 0:  19%|█▉        | 77/400 [00:00<00:02, 122.01it/s]
#
# Chain 0:  22%|██▎       | 90/400 [00:00<00:02, 121.74it/s]
#
# Chain 0:  26%|██▌       | 103/400 [00:00<00:02, 121.79it/s]
#
# Chain 0:  29%|██▉       | 116/400 [00:00<00:02, 121.91it/s]
#
# Chain 0:  32%|███▏      | 129/400 [00:01<00:02, 121.98it/s]
#
# Chain 0:  36%|███▌      | 142/400 [00:01<00:02, 122.11it/s]
#
# Chain 0:  39%|███▉      | 155/400 [00:01<00:02, 122.14it/s]
#
# Chain 0:  42%|████▏     | 168/400 [00:01<00:01, 122.20it/s]
#
# Chain 0:  45%|████▌     | 181/400 [00:01<00:01, 122.18it/s]
#
# Chain 0:  48%|████▊     | 194/400 [00:01<00:01, 122.20it/s]
#
# Chain 0:  52%|█████▏    | 207/400 [00:01<00:01, 122.23it/s]
#
# Chain 0:  55%|█████▌    | 220/400 [00:01<00:01, 122.28it/s]
#
# Chain 0:  58%|█████▊    | 233/400 [00:01<00:01, 122.30it/s]
#
# Chain 0:  62%|██████▏   | 246/400 [00:02<00:01, 122.29it/s]
#
# Chain 0:  65%|██████▍   | 259/400 [00:02<00:01, 122.27it/s]
#
# Chain 0:  68%|██████▊   | 272/400 [00:02<00:01, 122.18it/s]
#
# Chain 0:  71%|███████▏  | 285/400 [00:02<00:00, 122.15it/s]
#
# Chain 0:  74%|███████▍  | 298/400 [00:02<00:00, 122.19it/s]
#
# Chain 0:  78%|███████▊  | 311/400 [00:02<00:00, 122.21it/s]
#
# Chain 0:  81%|████████  | 324/400 [00:02<00:00, 122.25it/s]
#
# Chain 0:  84%|████████▍ | 337/400 [00:02<00:00, 122.29it/s]
#
# Chain 0:  88%|████████▊ | 350/400 [00:02<00:00, 122.33it/s]
#
# Chain 0:  91%|█████████ | 363/400 [00:02<00:00, 122.26it/s]
#
# Chain 0:  94%|█████████▍| 376/400 [00:03<00:00, 122.31it/s]
#
# Chain 0: 100%|██████████| 400/400 [00:03<00:00, 122.02it/s]
#
#
# Chain 0:   0%|          | 0/400 [00:00<?, ?it/s]
#
# Chain 0:   3%|▎         | 12/400 [00:00<00:03, 115.86it/s]
#
# Chain 0:   6%|▋         | 25/400 [00:00<00:03, 119.67it/s]
#
# Chain 0:  10%|▉         | 38/400 [00:00<00:02, 120.93it/s]
#
# Chain 0:  13%|█▎        | 51/400 [00:00<00:02, 121.40it/s]
#
# Chain 0:  16%|█▌        | 64/400 [00:00<00:02, 121.80it/s]
#
# Chain 0:  19%|█▉        | 77/400 [00:00<00:02, 122.02it/s]
#
# Chain 0:  22%|██▎       | 90/400 [00:00<00:02, 122.15it/s]
#
# Chain 0:  26%|██▌       | 103/400 [00:00<00:02, 122.24it/s]
#
# Chain 0:  29%|██▉       | 116/400 [00:00<00:02, 122.24it/s]
#
# Chain 0:  32%|███▏      | 129/400 [00:01<00:02, 122.28it/s]
#
# Chain 0:  36%|███▌      | 142/400 [00:01<00:02, 122.24it/s]
#
# Chain 0:  39%|███▉      | 155/400 [00:01<00:02, 122.35it/s]
#
# Chain 0:  42%|████▏     | 168/400 [00:01<00:01, 122.40it/s]
#
# Chain 0:  45%|████▌     | 181/400 [00:01<00:01, 122.36it/s]
#
# Chain 0:  48%|████▊     | 194/400 [00:01<00:01, 122.37it/s]
#
# Chain 0:  52%|█████▏    | 207/400 [00:01<00:01, 122.32it/s]
#
# Chain 0:  55%|█████▌    | 220/400 [00:01<00:01, 122.32it/s]
#
# Chain 0:  58%|█████▊    | 233/400 [00:01<00:01, 122.31it/s]
#
# Chain 0:  62%|██████▏   | 246/400 [00:02<00:01, 122.35it/s]
#
# Chain 0:  65%|██████▍   | 259/400 [00:02<00:01, 122.33it/s]
#
# Chain 0:  68%|██████▊   | 272/400 [00:02<00:01, 122.34it/s]
#
# Chain 0:  71%|███████▏  | 285/400 [00:02<00:00, 122.35it/s]
#
# Chain 0:  74%|███████▍  | 298/400 [00:02<00:00, 122.25it/s]
#
# Chain 0:  78%|███████▊  | 311/400 [00:02<00:00, 122.26it/s]
#
# Chain 0:  81%|████████  | 324/400 [00:02<00:00, 122.32it/s]
#
# Chain 0:  84%|████████▍ | 337/400 [00:02<00:00, 122.33it/s]
#
# Chain 0:  88%|████████▊ | 350/400 [00:02<00:00, 122.34it/s]
#
# Chain 0:  91%|█████████ | 363/400 [00:02<00:00, 122.41it/s]
#
# Chain 0:  94%|█████████▍| 376/400 [00:03<00:00, 122.45it/s]
#
# Chain 0: 100%|██████████| 400/400 [00:03<00:00, 122.14it/s]
#
#
# Chain 0:   0%|          | 0/400 [00:00<?, ?it/s]
#
# Chain 0:   3%|▎         | 12/400 [00:00<00:03, 116.41it/s]
#
# Chain 0:   6%|▋         | 25/400 [00:00<00:03, 119.98it/s]
#
# Chain 0:  10%|▉         | 38/400 [00:00<00:02, 121.03it/s]
#
# Chain 0:  13%|█▎        | 51/400 [00:00<00:02, 121.57it/s]
#
# Chain 0:  16%|█▌        | 64/400 [00:00<00:02, 121.81it/s]
#
# Chain 0:  19%|█▉        | 77/400 [00:00<00:02, 121.89it/s]
#
# Chain 0:  22%|██▎       | 90/400 [00:00<00:02, 121.70it/s]
#
# Chain 0:  26%|██▌       | 103/400 [00:00<00:02, 121.77it/s]
#
# Chain 0:  29%|██▉       | 116/400 [00:00<00:02, 121.90it/s]
#
# Chain 0:  32%|███▏      | 129/400 [00:01<00:02, 121.91it/s]
#
# Chain 0:  36%|███▌      | 142/400 [00:01<00:02, 122.02it/s]
#
# Chain 0:  39%|███▉      | 155/400 [00:01<00:02, 121.99it/s]
#
# Chain 0:  42%|████▏     | 168/400 [00:01<00:01, 122.03it/s]
#
# Chain 0:  45%|████▌     | 181/400 [00:01<00:01, 122.08it/s]
#
# Chain 0:  48%|████▊     | 194/400 [00:01<00:01, 122.10it/s]
#
# Chain 0:  52%|█████▏    | 207/400 [00:01<00:01, 122.00it/s]
#
# Chain 0:  55%|█████▌    | 220/400 [00:01<00:01, 122.00it/s]
#
# Chain 0:  58%|█████▊    | 233/400 [00:01<00:01, 121.99it/s]
#
# Chain 0:  62%|██████▏   | 246/400 [00:02<00:01, 121.83it/s]
#
# Chain 0:  65%|██████▍   | 259/400 [00:02<00:01, 121.97it/s]
#
# Chain 0:  68%|██████▊   | 272/400 [00:02<00:01, 122.05it/s]
#
# Chain 0:  71%|███████▏  | 285/400 [00:02<00:00, 121.99it/s]
#
# Chain 0:  74%|███████▍  | 298/400 [00:02<00:00, 122.12it/s]
#
# Chain 0:  78%|███████▊  | 311/400 [00:02<00:00, 122.11it/s]
#
# Chain 0:  81%|████████  | 324/400 [00:02<00:00, 122.10it/s]
#
# Chain 0:  84%|████████▍ | 337/400 [00:02<00:00, 122.15it/s]
#
# Chain 0:  88%|████████▊ | 350/400 [00:02<00:00, 122.11it/s]
#
# Chain 0:  91%|█████████ | 363/400 [00:02<00:00, 122.23it/s]
#
# Chain 0:  94%|█████████▍| 376/400 [00:03<00:00, 122.28it/s]
#
# Chain 0: 100%|██████████| 400/400 [00:03<00:00, 121.92it/s]
#
#
# Chain 0:   0%|          | 0/400 [00:00<?, ?it/s]
#
# Chain 0:   3%|▎         | 12/400 [00:00<00:03, 113.87it/s]
#
# Chain 0:   6%|▋         | 25/400 [00:00<00:03, 118.79it/s]
#
# Chain 0:  10%|▉         | 38/400 [00:00<00:03, 120.43it/s]
#
# Chain 0:  13%|█▎        | 51/400 [00:00<00:02, 121.11it/s]
#
# Chain 0:  16%|█▌        | 64/400 [00:00<00:02, 121.54it/s]
#
# Chain 0:  19%|█▉        | 77/400 [00:00<00:02, 121.71it/s]
#
# Chain 0:  22%|██▎       | 90/400 [00:00<00:02, 121.88it/s]
#
# Chain 0:  26%|██▌       | 103/400 [00:00<00:02, 121.98it/s]
#
# Chain 0:  29%|██▉       | 116/400 [00:00<00:02, 121.98it/s]
#
# Chain 0:  32%|███▏      | 129/400 [00:01<00:02, 121.99it/s]
#
# Chain 0:  36%|███▌      | 142/400 [00:01<00:02, 122.02it/s]
#
# Chain 0:  39%|███▉      | 155/400 [00:01<00:02, 122.07it/s]
#
# Chain 0:  42%|████▏     | 168/400 [00:01<00:01, 122.15it/s]
#
# Chain 0:  45%|████▌     | 181/400 [00:01<00:01, 122.26it/s]
#
# Chain 0:  48%|████▊     | 194/400 [00:01<00:01, 122.28it/s]
#
# Chain 0:  52%|█████▏    | 207/400 [00:01<00:01, 122.33it/s]
#
# Chain 0:  55%|█████▌    | 220/400 [00:01<00:01, 122.34it/s]
#
# Chain 0:  58%|█████▊    | 233/400 [00:01<00:01, 122.34it/s]
#
# Chain 0:  62%|██████▏   | 246/400 [00:02<00:01, 122.36it/s]
#
# Chain 0:  65%|██████▍   | 259/400 [00:02<00:01, 122.36it/s]
#
# Chain 0:  68%|██████▊   | 272/400 [00:02<00:01, 122.32it/s]
#
# Chain 0:  71%|███████▏  | 285/400 [00:02<00:00, 122.29it/s]
#
# Chain 0:  74%|███████▍  | 298/400 [00:02<00:00, 122.26it/s]
#
# Chain 0:  78%|███████▊  | 311/400 [00:02<00:00, 122.30it/s]
#
# Chain 0:  81%|████████  | 324/400 [00:02<00:00, 122.34it/s]
#
# Chain 0:  84%|████████▍ | 337/400 [00:02<00:00, 122.33it/s]
#
# Chain 0:  88%|████████▊ | 350/400 [00:02<00:00, 122.31it/s]
#
# Chain 0:  91%|█████████ | 363/400 [00:02<00:00, 122.34it/s]
#
# Chain 0:  94%|█████████▍| 376/400 [00:03<00:00, 122.33it/s]
#
# Chain 0: 100%|██████████| 400/400 [00:03<00:00, 121.98it/s]
#
#
# Chain 0:   0%|          | 0/400 [00:00<?, ?it/s]
#
# Chain 0:   3%|▎         | 12/400 [00:00<00:03, 116.20it/s]
#
# Chain 0:   6%|▋         | 25/400 [00:00<00:03, 119.61it/s]
#
# Chain 0:  10%|▉         | 38/400 [00:00<00:02, 120.85it/s]
#
# Chain 0:  13%|█▎        | 51/400 [00:00<00:02, 121.41it/s]
#
# Chain 0:  16%|█▌        | 64/400 [00:00<00:02, 121.66it/s]
#
# Chain 0:  19%|█▉        | 77/400 [00:00<00:02, 121.80it/s]
#
# Chain 0:  22%|██▎       | 90/400 [00:00<00:02, 121.95it/s]
#
# Chain 0:  26%|██▌       | 103/400 [00:00<00:02, 122.03it/s]
#
# Chain 0:  29%|██▉       | 116/400 [00:00<00:02, 122.06it/s]
#
# Chain 0:  32%|███▏      | 129/400 [00:01<00:02, 122.11it/s]
#
# Chain 0:  36%|███▌      | 142/400 [00:01<00:02, 122.16it/s]
#
# Chain 0:  39%|███▉      | 155/400 [00:01<00:02, 122.25it/s]
#
# Chain 0:  42%|████▏     | 168/400 [00:01<00:01, 122.27it/s]
#
# Chain 0:  45%|████▌     | 181/400 [00:01<00:01, 122.23it/s]
#
# Chain 0:  48%|████▊     | 194/400 [00:01<00:01, 122.23it/s]
#
# Chain 0:  52%|█████▏    | 207/400 [00:01<00:01, 122.32it/s]
#
# Chain 0:  55%|█████▌    | 220/400 [00:01<00:01, 122.26it/s]
#
# Chain 0:  58%|█████▊    | 233/400 [00:01<00:01, 122.20it/s]
#
# Chain 0:  62%|██████▏   | 246/400 [00:02<00:01, 122.15it/s]
#
# Chain 0:  65%|██████▍   | 259/400 [00:02<00:01, 122.20it/s]
#
# Chain 0:  68%|██████▊   | 272/400 [00:02<00:01, 122.18it/s]
#
# Chain 0:  71%|███████▏  | 285/400 [00:02<00:00, 122.17it/s]
#
# Chain 0:  74%|███████▍  | 298/400 [00:02<00:00, 122.21it/s]
#
# Chain 0:  78%|███████▊  | 311/400 [00:02<00:00, 122.26it/s]
#
# Chain 0:  81%|████████  | 324/400 [00:02<00:00, 122.25it/s]
#
# Chain 0:  84%|████████▍ | 337/400 [00:02<00:00, 122.23it/s]
#
# Chain 0:  88%|████████▊ | 350/400 [00:02<00:00, 122.26it/s]
#
# Chain 0:  91%|█████████ | 363/400 [00:02<00:00, 122.29it/s]
#
# Chain 0:  94%|█████████▍| 376/400 [00:03<00:00, 122.26it/s]
#
# Chain 0: 100%|██████████| 400/400 [00:03<00:00, 121.99it/s]
#
#
# Chain 0:   0%|          | 0/400 [00:00<?, ?it/s]
#
# Chain 0:   3%|▎         | 12/400 [00:00<00:03, 115.79it/s]
#
# Chain 0:   6%|▋         | 25/400 [00:00<00:03, 119.59it/s]
#
# Chain 0:  10%|▉         | 38/400 [00:00<00:02, 120.78it/s]
#
# Chain 0:  13%|█▎        | 51/400 [00:00<00:02, 121.15it/s]
#
# Chain 0:  16%|█▌        | 64/400 [00:00<00:02, 121.50it/s]
#
# Chain 0:  19%|█▉        | 77/400 [00:00<00:02, 121.79it/s]
#
# Chain 0:  22%|██▎       | 90/400 [00:00<00:02, 121.87it/s]
#
# Chain 0:  26%|██▌       | 103/400 [00:00<00:02, 121.89it/s]
#
# Chain 0:  29%|██▉       | 116/400 [00:00<00:02, 121.90it/s]
#
# Chain 0:  32%|███▏      | 129/400 [00:01<00:02, 122.03it/s]
#
# Chain 0:  36%|███▌      | 142/400 [00:01<00:02, 122.09it/s]
#
# Chain 0:  39%|███▉      | 155/400 [00:01<00:02, 122.06it/s]
#
# Chain 0:  42%|████▏     | 168/400 [00:01<00:01, 122.12it/s]
#
# Chain 0:  45%|████▌     | 181/400 [00:01<00:01, 122.13it/s]
#
# Chain 0:  48%|████▊     | 194/400 [00:01<00:01, 122.18it/s]
#
# Chain 0:  52%|█████▏    | 207/400 [00:01<00:01, 122.18it/s]
#
# Chain 0:  55%|█████▌    | 220/400 [00:01<00:01, 122.21it/s]
#
# Chain 0:  58%|█████▊    | 233/400 [00:01<00:01, 122.20it/s]
#
# Chain 0:  62%|██████▏   | 246/400 [00:02<00:01, 122.20it/s]
#
# Chain 0:  65%|██████▍   | 259/400 [00:02<00:01, 122.21it/s]
#
# Chain 0:  68%|██████▊   | 272/400 [00:02<00:01, 122.19it/s]
#
# Chain 0:  71%|███████▏  | 285/400 [00:02<00:00, 122.29it/s]
#
# Chain 0:  74%|███████▍  | 298/400 [00:02<00:00, 122.29it/s]
#
# Chain 0:  78%|███████▊  | 311/400 [00:02<00:00, 122.28it/s]
#
# Chain 0:  81%|████████  | 324/400 [00:02<00:00, 122.06it/s]
#
# Chain 0:  84%|████████▍ | 337/400 [00:02<00:00, 122.21it/s]
#
# Chain 0:  88%|████████▊ | 350/400 [00:02<00:00, 122.24it/s]
#
# Chain 0:  91%|█████████ | 363/400 [00:02<00:00, 122.31it/s]
#
# Chain 0:  94%|█████████▍| 376/400 [00:03<00:00, 122.36it/s]
#
# Chain 0: 100%|██████████| 400/400 [00:03<00:00, 121.99it/s]
#
#
# Chain 0:   0%|          | 0/400 [00:00<?, ?it/s]
#
# Chain 0:   3%|▎         | 12/400 [00:00<00:03, 116.13it/s]
#
# Chain 0:   6%|▋         | 25/400 [00:00<00:03, 119.63it/s]
#
# Chain 0:  10%|▉         | 38/400 [00:00<00:02, 120.85it/s]
#
# Chain 0:  13%|█▎        | 51/400 [00:00<00:02, 121.32it/s]
#
# Chain 0:  16%|█▌        | 64/400 [00:00<00:02, 121.69it/s]
#
# Chain 0:  19%|█▉        | 77/400 [00:00<00:02, 121.98it/s]
#
# Chain 0:  22%|██▎       | 90/400 [00:00<00:02, 122.14it/s]
#
# Chain 0:  26%|██▌       | 103/400 [00:00<00:02, 122.00it/s]
#
# Chain 0:  29%|██▉       | 116/400 [00:00<00:02, 122.12it/s]
#
# Chain 0:  32%|███▏      | 129/400 [00:01<00:02, 122.24it/s]
#
# Chain 0:  36%|███▌      | 142/400 [00:01<00:02, 122.18it/s]
#
# Chain 0:  39%|███▉      | 155/400 [00:01<00:02, 122.27it/s]
#
# Chain 0:  42%|████▏     | 168/400 [00:01<00:01, 122.26it/s]
#
# Chain 0:  45%|████▌     | 181/400 [00:01<00:01, 122.27it/s]
#
# Chain 0:  48%|████▊     | 194/400 [00:01<00:01, 122.28it/s]
#
# Chain 0:  52%|█████▏    | 207/400 [00:01<00:01, 122.35it/s]
#
# Chain 0:  55%|█████▌    | 220/400 [00:01<00:01, 122.22it/s]
#
# Chain 0:  58%|█████▊    | 233/400 [00:01<00:01, 122.33it/s]
#
# Chain 0:  62%|██████▏   | 246/400 [00:02<00:01, 122.36it/s]
#
# Chain 0:  65%|██████▍   | 259/400 [00:02<00:01, 122.39it/s]
#
# Chain 0:  68%|██████▊   | 272/400 [00:02<00:01, 122.29it/s]
#
# Chain 0:  71%|███████▏  | 285/400 [00:02<00:00, 122.24it/s]
#
# Chain 0:  74%|███████▍  | 298/400 [00:02<00:00, 122.27it/s]
#
# Chain 0:  78%|███████▊  | 311/400 [00:02<00:00, 122.25it/s]
#
# Chain 0:  81%|████████  | 324/400 [00:02<00:00, 122.31it/s]
#
# Chain 0:  84%|████████▍ | 337/400 [00:02<00:00, 122.23it/s]
#
# Chain 0:  88%|████████▊ | 350/400 [00:02<00:00, 122.19it/s]
#
# Chain 0:  91%|█████████ | 363/400 [00:02<00:00, 122.20it/s]
#
# Chain 0:  94%|█████████▍| 376/400 [00:03<00:00, 122.21it/s]
#
# Chain 0: 100%|██████████| 400/400 [00:03<00:00, 122.05it/s]
#
#
# Chain 0:   0%|          | 0/400 [00:00<?, ?it/s]
#
# Chain 0:   3%|▎         | 12/400 [00:00<00:03, 116.02it/s]
#
# Chain 0:   6%|▋         | 25/400 [00:00<00:03, 119.82it/s]
#
# Chain 0:  10%|▉         | 38/400 [00:00<00:02, 120.97it/s]
#
# Chain 0:  13%|█▎        | 51/400 [00:00<00:02, 121.45it/s]
#
# Chain 0:  16%|█▌        | 64/400 [00:00<00:02, 121.72it/s]
#
# Chain 0:  19%|█▉        | 77/400 [00:00<00:02, 121.93it/s]
#
# Chain 0:  22%|██▎       | 90/400 [00:00<00:02, 122.06it/s]
#
# Chain 0:  26%|██▌       | 103/400 [00:00<00:02, 122.13it/s]
#
# Chain 0:  29%|██▉       | 116/400 [00:00<00:02, 122.08it/s]
#
# Chain 0:  32%|███▏      | 129/400 [00:01<00:02, 122.12it/s]
#
# Chain 0:  36%|███▌      | 142/400 [00:01<00:02, 122.04it/s]
#
# Chain 0:  39%|███▉      | 155/400 [00:01<00:02, 122.12it/s]
#
# Chain 0:  42%|████▏     | 168/400 [00:01<00:01, 122.20it/s]
#
# Chain 0:  45%|████▌     | 181/400 [00:01<00:01, 122.21it/s]
#
# Chain 0:  48%|████▊     | 194/400 [00:01<00:01, 122.20it/s]
#
# Chain 0:  52%|█████▏    | 207/400 [00:01<00:01, 122.22it/s]
#
# Chain 0:  55%|█████▌    | 220/400 [00:01<00:01, 122.28it/s]
#
# Chain 0:  58%|█████▊    | 233/400 [00:01<00:01, 122.30it/s]
#
# Chain 0:  62%|██████▏   | 246/400 [00:02<00:01, 122.17it/s]
#
# Chain 0:  65%|██████▍   | 259/400 [00:02<00:01, 122.15it/s]
#
# Chain 0:  68%|██████▊   | 272/400 [00:02<00:01, 122.17it/s]
#
# Chain 0:  71%|███████▏  | 285/400 [00:02<00:00, 122.05it/s]
#
# Chain 0:  74%|███████▍  | 298/400 [00:02<00:00, 122.12it/s]
#
# Chain 0:  78%|███████▊  | 311/400 [00:02<00:00, 122.08it/s]
#
# Chain 0:  81%|████████  | 324/400 [00:02<00:00, 122.24it/s]
#
# Chain 0:  84%|████████▍ | 337/400 [00:02<00:00, 122.28it/s]
#
# Chain 0:  88%|████████▊ | 350/400 [00:02<00:00, 122.27it/s]
#
# Chain 0:  91%|█████████ | 363/400 [00:02<00:00, 122.33it/s]
#
# Chain 0:  94%|█████████▍| 376/400 [00:03<00:00, 122.39it/s]
#
# Chain 0: 100%|██████████| 400/400 [00:03<00:00, 122.05it/s]
#
#
# Chain 0:   0%|          | 0/400 [00:00<?, ?it/s]
#
# Chain 0:   3%|▎         | 12/400 [00:00<00:03, 116.43it/s]
#
# Chain 0:   6%|▋         | 25/400 [00:00<00:03, 119.84it/s]
#
# Chain 0:  10%|▉         | 38/400 [00:00<00:02, 120.98it/s]
#
# Chain 0:  13%|█▎        | 51/400 [00:00<00:02, 121.56it/s]
#
# Chain 0:  16%|█▌        | 64/400 [00:00<00:02, 121.87it/s]
#
# Chain 0:  19%|█▉        | 77/400 [00:00<00:02, 121.92it/s]
#
# Chain 0:  22%|██▎       | 90/400 [00:00<00:02, 122.09it/s]
#
# Chain 0:  26%|██▌       | 103/400 [00:00<00:02, 122.23it/s]
#
# Chain 0:  29%|██▉       | 116/400 [00:00<00:02, 122.27it/s]
#
# Chain 0:  32%|███▏      | 129/400 [00:01<00:02, 122.19it/s]
#
# Chain 0:  36%|███▌      | 142/400 [00:01<00:02, 122.20it/s]
#
# Chain 0:  39%|███▉      | 155/400 [00:01<00:02, 122.27it/s]
#
# Chain 0:  42%|████▏     | 168/400 [00:01<00:01, 122.30it/s]
#
# Chain 0:  45%|████▌     | 181/400 [00:01<00:01, 122.33it/s]
#
# Chain 0:  48%|████▊     | 194/400 [00:01<00:01, 122.34it/s]
#
# Chain 0:  52%|█████▏    | 207/400 [00:01<00:01, 122.39it/s]
#
# Chain 0:  55%|█████▌    | 220/400 [00:01<00:01, 122.35it/s]
#
# Chain 0:  58%|█████▊    | 233/400 [00:01<00:01, 122.35it/s]
#
# Chain 0:  62%|██████▏   | 246/400 [00:02<00:01, 122.30it/s]
#
# Chain 0:  65%|██████▍   | 259/400 [00:02<00:01, 122.34it/s]
#
# Chain 0:  68%|██████▊   | 272/400 [00:02<00:01, 122.39it/s]
#
# Chain 0:  71%|███████▏  | 285/400 [00:02<00:00, 122.36it/s]
#
# Chain 0:  74%|███████▍  | 298/400 [00:02<00:00, 122.36it/s]
#
# Chain 0:  78%|███████▊  | 311/400 [00:02<00:00, 122.36it/s]
#
# Chain 0:  81%|████████  | 324/400 [00:02<00:00, 122.39it/s]
#
# ...
#
# Chain 0:  88%|████████▊ | 350/400 [00:02<00:00, 122.31it/s]
#
# Chain 0:  91%|█████████ | 363/400 [00:02<00:00, 122.38it/s]
#
# Chain 0:  94%|█████████▍| 376/400 [00:03<00:00, 122.36it/s]
#
# Chain 0: 100%|██████████| 400/400 [00:03<00:00, 122.26it/s]
#
#
# Chain 0:   0%|          | 0/400 [00:00<?, ?it/s]
#
# Chain 0:   3%|▎         | 12/400 [00:00<00:03, 116.39it/s]
#
# Chain 0:   6%|▋         | 25/400 [00:00<00:03, 119.93it/s]
#
# Chain 0:  10%|▉         | 38/400 [00:00<00:02, 121.21it/s]
#
# Chain 0:  13%|█▎        | 51/400 [00:00<00:02, 121.72it/s]
#
# Chain 0:  16%|█▌        | 64/400 [00:00<00:02, 121.87it/s]
#
# Chain 0:  19%|█▉        | 77/400 [00:00<00:02, 122.08it/s]
#
# Chain 0:  22%|██▎       | 90/400 [00:00<00:02, 122.22it/s]
#
# Chain 0:  26%|██▌       | 103/400 [00:00<00:02, 122.31it/s]
#
# Chain 0:  29%|██▉       | 116/400 [00:00<00:02, 122.43it/s]
#
# Chain 0:  32%|███▏      | 129/400 [00:01<00:02, 122.42it/s]
#
# Chain 0:  36%|███▌      | 142/400 [00:01<00:02, 122.46it/s]
#
# Chain 0:  39%|███▉      | 155/400 [00:01<00:02, 122.48it/s]
#
# Chain 0:  42%|████▏     | 168/400 [00:01<00:01, 122.44it/s]
#
# Chain 0:  45%|████▌     | 181/400 [00:01<00:01, 122.44it/s]
#
# Chain 0:  48%|████▊     | 194/400 [00:01<00:01, 122.47it/s]
#
# Chain 0:  52%|█████▏    | 207/400 [00:01<00:01, 122.31it/s]
#
# Chain 0:  55%|█████▌    | 220/400 [00:01<00:01, 122.04it/s]
#
# Chain 0:  58%|█████▊    | 233/400 [00:01<00:01, 122.00it/s]
#
# Chain 0:  62%|██████▏   | 246/400 [00:02<00:01, 122.04it/s]
#
# Chain 0:  65%|██████▍   | 259/400 [00:02<00:01, 122.12it/s]
#
# Chain 0:  68%|██████▊   | 272/400 [00:02<00:01, 122.12it/s]
#
# Chain 0:  71%|███████▏  | 285/400 [00:02<00:00, 122.18it/s]
#
# Chain 0:  74%|███████▍  | 298/400 [00:02<00:00, 122.22it/s]
#
# Chain 0:  78%|███████▊  | 311/400 [00:02<00:00, 122.14it/s]
#
# Chain 0:  81%|████████  | 324/400 [00:02<00:00, 122.10it/s]
#
# Chain 0:  84%|████████▍ | 337/400 [00:02<00:00, 122.16it/s]
#
# Chain 0:  88%|████████▊ | 350/400 [00:02<00:00, 122.24it/s]
#
# Chain 0:  91%|█████████ | 363/400 [00:02<00:00, 122.31it/s]
#
# Chain 0:  94%|█████████▍| 376/400 [00:03<00:00, 122.39it/s]
#
# Chain 0: 100%|██████████| 400/400 [00:03<00:00, 122.12it/s]
#
#
# Chain 0:   0%|          | 0/400 [00:00<?, ?it/s]
#
# Chain 0:   3%|▎         | 12/400 [00:00<00:03, 116.27it/s]
#
# Chain 0:   6%|▋         | 25/400 [00:00<00:03, 119.91it/s]
#
# Chain 0:  10%|▉         | 38/400 [00:00<00:02, 121.10it/s]
#
# Chain 0:  13%|█▎        | 51/400 [00:00<00:02, 121.63it/s]
#
# Chain 0:  16%|█▌        | 64/400 [00:00<00:02, 121.89it/s]
#
# Chain 0:  19%|█▉        | 77/400 [00:00<00:02, 122.16it/s]
#
# Chain 0:  22%|██▎       | 90/400 [00:00<00:02, 122.22it/s]
#
# Chain 0:  26%|██▌       | 103/400 [00:00<00:02, 122.27it/s]
#
# Chain 0:  29%|██▉       | 116/400 [00:00<00:02, 122.35it/s]
#
# Chain 0:  32%|███▏      | 129/400 [00:01<00:02, 122.44it/s]
#
# Chain 0:  36%|███▌      | 142/400 [00:01<00:02, 122.47it/s]
#
# Chain 0:  39%|███▉      | 155/400 [00:01<00:01, 122.54it/s]
#
# Chain 0:  42%|████▏     | 168/400 [00:01<00:01, 122.48it/s]
#
# Chain 0:  45%|████▌     | 181/400 [00:01<00:01, 122.48it/s]
#
# Chain 0:  48%|████▊     | 194/400 [00:01<00:01, 122.39it/s]
#
# Chain 0:  52%|█████▏    | 207/400 [00:01<00:01, 122.47it/s]
#
# Chain 0:  55%|█████▌    | 220/400 [00:01<00:01, 122.45it/s]
#
# Chain 0:  58%|█████▊    | 233/400 [00:01<00:01, 122.52it/s]
#
# Chain 0:  62%|██████▏   | 246/400 [00:02<00:01, 122.47it/s]
#
# Chain 0:  65%|██████▍   | 259/400 [00:02<00:01, 122.51it/s]
#
# Chain 0:  68%|██████▊   | 272/400 [00:02<00:01, 122.52it/s]
#
# Chain 0:  71%|███████▏  | 285/400 [00:02<00:00, 122.50it/s]
#
# Chain 0:  74%|███████▍  | 298/400 [00:02<00:00, 122.51it/s]
#
# Chain 0:  78%|███████▊  | 311/400 [00:02<00:00, 122.55it/s]
#
# Chain 0:  81%|████████  | 324/400 [00:02<00:00, 122.59it/s]
#
# Chain 0:  84%|████████▍ | 337/400 [00:02<00:00, 122.60it/s]
#
# Chain 0:  88%|████████▊ | 350/400 [00:02<00:00, 122.64it/s]
#
# Chain 0:  91%|█████████ | 363/400 [00:02<00:00, 122.71it/s]
#
# Chain 0:  94%|█████████▍| 376/400 [00:03<00:00, 122.63it/s]
#
# Chain 0: 100%|██████████| 400/400 [00:03<00:00, 122.32it/s]
#
#
# Chain 0:   0%|          | 0/400 [00:00<?, ?it/s]
#
# Chain 0:   3%|▎         | 12/400 [00:00<00:03, 116.43it/s]
#
# Chain 0:   6%|▋         | 25/400 [00:00<00:03, 120.13it/s]
#
# Chain 0:  10%|▉         | 38/400 [00:00<00:02, 121.18it/s]
#
# Chain 0:  13%|█▎        | 51/400 [00:00<00:02, 121.73it/s]
#
# Chain 0:  16%|█▌        | 64/400 [00:00<00:02, 122.10it/s]
#
# Chain 0:  19%|█▉        | 77/400 [00:00<00:02, 122.26it/s]
#
# Chain 0:  22%|██▎       | 90/400 [00:00<00:02, 122.29it/s]
#
# Chain 0:  26%|██▌       | 103/400 [00:00<00:02, 122.41it/s]
#
# Chain 0:  29%|██▉       | 116/400 [00:00<00:02, 122.38it/s]
#
# Chain 0:  32%|███▏      | 129/400 [00:01<00:02, 122.39it/s]
#
# Chain 0:  36%|███▌      | 142/400 [00:01<00:02, 122.43it/s]
#
# Chain 0:  39%|███▉      | 155/400 [00:01<00:02, 122.33it/s]
#
# Chain 0:  42%|████▏     | 168/400 [00:01<00:01, 122.49it/s]
#
# Chain 0:  45%|████▌     | 181/400 [00:01<00:01, 122.56it/s]
#
# Chain 0:  48%|████▊     | 194/400 [00:01<00:01, 122.57it/s]
#
# Chain 0:  52%|█████▏    | 207/400 [00:01<00:01, 122.61it/s]
#
# Chain 0:  55%|█████▌    | 220/400 [00:01<00:01, 122.62it/s]
#
# Chain 0:  58%|█████▊    | 233/400 [00:01<00:01, 122.62it/s]
#
# Chain 0:  62%|██████▏   | 246/400 [00:02<00:01, 122.61it/s]
#
# Chain 0:  65%|██████▍   | 259/400 [00:02<00:01, 122.58it/s]
#
# Chain 0:  68%|██████▊   | 272/400 [00:02<00:01, 122.49it/s]
#
# Chain 0:  71%|███████▏  | 285/400 [00:02<00:00, 122.49it/s]
#
# Chain 0:  74%|███████▍  | 298/400 [00:02<00:00, 122.47it/s]
#
# Chain 0:  78%|███████▊  | 311/400 [00:02<00:00, 122.42it/s]
#
# Chain 0:  81%|████████  | 324/400 [00:02<00:00, 122.46it/s]
#
# Chain 0:  84%|████████▍ | 337/400 [00:02<00:00, 122.51it/s]
#
# Chain 0:  88%|████████▊ | 350/400 [00:02<00:00, 122.51it/s]
#
# Chain 0:  91%|█████████ | 363/400 [00:02<00:00, 122.36it/s]
#
# Chain 0:  94%|█████████▍| 376/400 [00:03<00:00, 122.40it/s]
#
# Chain 0: 100%|██████████| 400/400 [00:03<00:00, 122.31it/s]
#
#
# Chain 0:   0%|          | 0/400 [00:00<?, ?it/s]
#
# Chain 0:   3%|▎         | 12/400 [00:00<00:03, 116.27it/s]
#
# Chain 0:   6%|▋         | 25/400 [00:00<00:03, 119.88it/s]
#
# Chain 0:  10%|▉         | 38/400 [00:00<00:02, 121.15it/s]
#
# Chain 0:  13%|█▎        | 51/400 [00:00<00:02, 121.60it/s]
#
# Chain 0:  16%|█▌        | 64/400 [00:00<00:02, 121.91it/s]
#
# Chain 0:  19%|█▉        | 77/400 [00:00<00:02, 122.08it/s]
#
# Chain 0:  22%|██▎       | 90/400 [00:00<00:02, 122.23it/s]
#
# Chain 0:  26%|██▌       | 103/400 [00:00<00:02, 122.27it/s]
#
# Chain 0:  29%|██▉       | 116/400 [00:00<00:02, 122.34it/s]
#
# Chain 0:  32%|███▏      | 129/400 [00:01<00:02, 122.41it/s]
#
# Chain 0:  36%|███▌      | 142/400 [00:01<00:02, 122.48it/s]
#
# Chain 0:  39%|███▉      | 155/400 [00:01<00:02, 122.46it/s]
#
# Chain 0:  42%|████▏     | 168/400 [00:01<00:01, 122.39it/s]
#
# Chain 0:  45%|████▌     | 181/400 [00:01<00:01, 122.34it/s]
#
# Chain 0:  48%|████▊     | 194/400 [00:01<00:01, 122.43it/s]
#
# Chain 0:  52%|█████▏    | 207/400 [00:01<00:01, 121.85it/s]
#
# Chain 0:  55%|█████▌    | 220/400 [00:01<00:01, 120.56it/s]
#
# Chain 0:  58%|█████▊    | 233/400 [00:01<00:01, 119.97it/s]
#
# Chain 0:  61%|██████▏   | 245/400 [00:02<00:01, 119.78it/s]
#
# Chain 0:  64%|██████▍   | 257/400 [00:02<00:01, 119.71it/s]
#
# Chain 0:  68%|██████▊   | 270/400 [00:02<00:01, 120.02it/s]
#
# Chain 0:  71%|███████   | 283/400 [00:02<00:00, 120.30it/s]
#
# Chain 0:  74%|███████▍  | 296/400 [00:02<00:00, 120.54it/s]
#
# Chain 0:  77%|███████▋  | 309/400 [00:02<00:00, 120.82it/s]
#
# Chain 0:  80%|████████  | 322/400 [00:02<00:00, 121.01it/s]
#
# Chain 0:  84%|████████▍ | 335/400 [00:02<00:00, 121.12it/s]
#
# Chain 0:  87%|████████▋ | 348/400 [00:02<00:00, 121.44it/s]
#
# Chain 0:  90%|█████████ | 361/400 [00:02<00:00, 121.61it/s]
#
# Chain 0:  94%|█████████▎| 374/400 [00:03<00:00, 121.72it/s]
#
# Chain 0:  97%|█████████▋| 387/400 [00:03<00:00, 121.88it/s]
#
# Chain 0: 100%|██████████| 400/400 [00:03<00:00, 121.37it/s]
#
#
# Chain 0:   0%|          | 0/400 [00:00<?, ?it/s]
#
# Chain 0:   3%|▎         | 12/400 [00:00<00:03, 116.06it/s]
#
# Chain 0:   6%|▋         | 25/400 [00:00<00:03, 119.66it/s]
#
# Chain 0:  10%|▉         | 38/400 [00:00<00:03, 120.66it/s]
#
# Chain 0:  13%|█▎        | 51/400 [00:00<00:02, 121.31it/s]
#
# Chain 0:  16%|█▌        | 64/400 [00:00<00:02, 121.68it/s]
#
# Chain 0:  19%|█▉        | 77/400 [00:00<00:02, 121.93it/s]
#
# Chain 0:  22%|██▎       | 90/400 [00:00<00:02, 122.12it/s]
#
# Chain 0:  26%|██▌       | 103/400 [00:00<00:02, 122.17it/s]
#
# Chain 0:  29%|██▉       | 116/400 [00:00<00:02, 122.29it/s]
#
# Chain 0:  32%|███▏      | 129/400 [00:01<00:02, 122.32it/s]
#
# Chain 0:  36%|███▌      | 142/400 [00:01<00:02, 122.31it/s]
#
# Chain 0:  39%|███▉      | 155/400 [00:01<00:02, 122.35it/s]
#
# Chain 0:  42%|████▏     | 168/400 [00:01<00:01, 122.32it/s]
#
# Chain 0:  45%|████▌     | 181/400 [00:01<00:01, 122.38it/s]
#
# Chain 0:  48%|████▊     | 194/400 [00:01<00:01, 122.40it/s]
#
# Chain 0:  52%|█████▏    | 207/400 [00:01<00:01, 122.44it/s]
#
# Chain 0:  55%|█████▌    | 220/400 [00:01<00:01, 122.40it/s]
#
# Chain 0:  58%|█████▊    | 233/400 [00:01<00:01, 122.41it/s]
#
# Chain 0:  62%|██████▏   | 246/400 [00:02<00:01, 122.44it/s]
#
# Chain 0:  65%|██████▍   | 259/400 [00:02<00:01, 122.48it/s]
#
# Chain 0:  68%|██████▊   | 272/400 [00:02<00:01, 122.45it/s]
#
# Chain 0:  71%|███████▏  | 285/400 [00:02<00:00, 122.32it/s]
#
# Chain 0:  74%|███████▍  | 298/400 [00:02<00:00, 122.28it/s]
#
# Chain 0:  78%|███████▊  | 311/400 [00:02<00:00, 122.34it/s]
#
# Chain 0:  81%|████████  | 324/400 [00:02<00:00, 122.35it/s]
#
# Chain 0:  84%|████████▍ | 337/400 [00:02<00:00, 122.38it/s]
#
# Chain 0:  88%|████████▊ | 350/400 [00:02<00:00, 122.42it/s]
#
# Chain 0:  91%|█████████ | 363/400 [00:02<00:00, 122.45it/s]
#
# Chain 0:  94%|█████████▍| 376/400 [00:03<00:00, 122.42it/s]
#
# Chain 0: 100%|██████████| 400/400 [00:03<00:00, 122.17it/s]
#
#
# Chain 0:   0%|          | 0/400 [00:00<?, ?it/s]
#
# Chain 0:   3%|▎         | 12/400 [00:00<00:03, 116.21it/s]
#
# Chain 0:   6%|▋         | 25/400 [00:00<00:03, 119.91it/s]
#
# Chain 0:  10%|▉         | 38/400 [00:00<00:02, 121.16it/s]
#
# Chain 0:  13%|█▎        | 51/400 [00:00<00:02, 121.68it/s]
#
# Chain 0:  16%|█▌        | 64/400 [00:00<00:02, 121.95it/s]
#
# Chain 0:  19%|█▉        | 77/400 [00:00<00:02, 122.20it/s]
#
# Chain 0:  22%|██▎       | 90/400 [00:00<00:02, 122.22it/s]
#
# Chain 0:  26%|██▌       | 103/400 [00:00<00:02, 122.23it/s]
#
# Chain 0:  29%|██▉       | 116/400 [00:00<00:02, 122.29it/s]
#
# Chain 0:  32%|███▏      | 129/400 [00:01<00:02, 122.36it/s]
#
# Chain 0:  36%|███▌      | 142/400 [00:01<00:02, 122.36it/s]
#
# Chain 0:  39%|███▉      | 155/400 [00:01<00:02, 122.34it/s]
#
# Chain 0:  42%|████▏     | 168/400 [00:01<00:01, 122.37it/s]
#
# Chain 0:  45%|████▌     | 181/400 [00:01<00:01, 122.44it/s]
#
# Chain 0:  48%|████▊     | 194/400 [00:01<00:01, 122.35it/s]
#
# Chain 0:  52%|█████▏    | 207/400 [00:01<00:01, 122.31it/s]
#
# Chain 0:  55%|█████▌    | 220/400 [00:01<00:01, 122.36it/s]
#
# Chain 0:  58%|█████▊    | 233/400 [00:01<00:01, 122.25it/s]
#
# Chain 0:  62%|██████▏   | 246/400 [00:02<00:01, 122.19it/s]
#
# Chain 0:  65%|██████▍   | 259/400 [00:02<00:01, 122.29it/s]
#
# Chain 0:  68%|██████▊   | 272/400 [00:02<00:01, 122.25it/s]
#
# Chain 0:  71%|███████▏  | 285/400 [00:02<00:00, 122.33it/s]
#
# Chain 0:  74%|███████▍  | 298/400 [00:02<00:00, 122.42it/s]
#
# Chain 0:  78%|███████▊  | 311/400 [00:02<00:00, 122.41it/s]
#
# Chain 0:  81%|████████  | 324/400 [00:02<00:00, 122.50it/s]
#
# Chain 0:  84%|████████▍ | 337/400 [00:02<00:00, 122.42it/s]
#
# Chain 0:  88%|████████▊ | 350/400 [00:02<00:00, 122.50it/s]
#
# Chain 0:  91%|█████████ | 363/400 [00:02<00:00, 122.51it/s]
#
# Chain 0:  94%|█████████▍| 376/400 [00:03<00:00, 122.49it/s]
#
# Chain 0: 100%|██████████| 400/400 [00:03<00:00, 122.21it/s]
#
#
# Chain 0:   0%|          | 0/400 [00:00<?, ?it/s]
#
# Chain 0:   3%|▎         | 12/400 [00:00<00:03, 116.43it/s]
#
# Chain 0:   6%|▋         | 25/400 [00:00<00:03, 120.04it/s]
#
# Chain 0:  10%|▉         | 38/400 [00:00<00:02, 121.09it/s]
#
# Chain 0:  13%|█▎        | 51/400 [00:00<00:02, 121.62it/s]
#
# Chain 0:  16%|█▌        | 64/400 [00:00<00:02, 121.95it/s]
#
# Chain 0:  19%|█▉        | 77/400 [00:00<00:02, 121.24it/s]
#
# Chain 0:  22%|██▎       | 90/400 [00:00<00:02, 121.62it/s]
#
# Chain 0:  26%|██▌       | 103/400 [00:00<00:02, 121.96it/s]
#
# Chain 0:  29%|██▉       | 116/400 [00:00<00:02, 122.19it/s]
#
# Chain 0:  32%|███▏      | 129/400 [00:01<00:02, 122.26it/s]
#
# Chain 0:  36%|███▌      | 142/400 [00:01<00:02, 122.33it/s]
#
# Chain 0:  39%|███▉      | 155/400 [00:01<00:02, 122.29it/s]
#
# Chain 0:  42%|████▏     | 168/400 [00:01<00:01, 122.39it/s]
#
# Chain 0:  45%|████▌     | 181/400 [00:01<00:01, 122.37it/s]
#
# Chain 0:  48%|████▊     | 194/400 [00:01<00:01, 122.34it/s]
#
# Chain 0:  52%|█████▏    | 207/400 [00:01<00:01, 122.42it/s]
#
# Chain 0:  55%|█████▌    | 220/400 [00:01<00:01, 122.46it/s]
#
# Chain 0:  58%|█████▊    | 233/400 [00:01<00:01, 122.46it/s]
#
# Chain 0:  62%|██████▏   | 246/400 [00:02<00:01, 122.47it/s]
#
# Chain 0:  65%|██████▍   | 259/400 [00:02<00:01, 122.47it/s]
#
# Chain 0:  68%|██████▊   | 272/400 [00:02<00:01, 122.51it/s]
#
# Chain 0:  71%|███████▏  | 285/400 [00:02<00:00, 122.48it/s]
#
# Chain 0:  74%|███████▍  | 298/400 [00:02<00:00, 122.48it/s]
#
# Chain 0:  78%|███████▊  | 311/400 [00:02<00:00, 122.60it/s]
#
# Chain 0:  81%|████████  | 324/400 [00:02<00:00, 122.61it/s]
#
# Chain 0:  84%|████████▍ | 337/400 [00:02<00:00, 122.59it/s]
#
# Chain 0:  88%|████████▊ | 350/400 [00:02<00:00, 122.56it/s]
#
# Chain 0:  91%|█████████ | 363/400 [00:02<00:00, 122.57it/s]
#
# Chain 0:  94%|█████████▍| 376/400 [00:03<00:00, 122.55it/s]
#
# Chain 0: 100%|██████████| 400/400 [00:03<00:00, 122.22it/s]
#
#
# Chain 0:   0%|          | 0/400 [00:00<?, ?it/s]
#
# Chain 0:   3%|▎         | 12/400 [00:00<00:03, 116.81it/s]
#
# Chain 0:   6%|▋         | 25/400 [00:00<00:03, 120.23it/s]
#
# Chain 0:  10%|▉         | 38/400 [00:00<00:02, 121.33it/s]
#
# Chain 0:  13%|█▎        | 51/400 [00:00<00:02, 121.79it/s]
#
# Chain 0:  16%|█▌        | 64/400 [00:00<00:02, 122.13it/s]
#
# Chain 0:  19%|█▉        | 77/400 [00:00<00:02, 122.24it/s]
#
# Chain 0:  22%|██▎       | 90/400 [00:00<00:02, 122.33it/s]
#
# Chain 0:  26%|██▌       | 103/400 [00:00<00:02, 122.31it/s]
#
# Chain 0:  29%|██▉       | 116/400 [00:00<00:02, 122.40it/s]
#
# Chain 0:  32%|███▏      | 129/400 [00:01<00:02, 122.41it/s]
#
# Chain 0:  36%|███▌      | 142/400 [00:01<00:02, 122.44it/s]
#
# Chain 0:  39%|███▉      | 155/400 [00:01<00:02, 122.33it/s]
#
# Chain 0:  42%|████▏     | 168/400 [00:01<00:01, 122.47it/s]
#
# Chain 0:  45%|████▌     | 181/400 [00:01<00:01, 122.45it/s]
#
# Chain 0:  48%|████▊     | 194/400 [00:01<00:01, 122.50it/s]
#
# Chain 0:  52%|█████▏    | 207/400 [00:01<00:01, 122.46it/s]
#
# Chain 0:  55%|█████▌    | 220/400 [00:01<00:01, 122.46it/s]
#
# Chain 0:  58%|█████▊    | 233/400 [00:01<00:01, 122.45it/s]
#
# Chain 0:  62%|██████▏   | 246/400 [00:02<00:01, 122.26it/s]
#
# Chain 0:  65%|██████▍   | 259/400 [00:02<00:01, 122.10it/s]
#
# Chain 0:  68%|██████▊   | 272/400 [00:02<00:01, 122.21it/s]
#
# Chain 0:  71%|███████▏  | 285/400 [00:02<00:00, 122.32it/s]
#
# Chain 0:  74%|███████▍  | 298/400 [00:02<00:00, 122.42it/s]
#
# Chain 0:  78%|███████▊  | 311/400 [00:02<00:00, 122.45it/s]
#
# Chain 0:  81%|████████  | 324/400 [00:02<00:00, 122.44it/s]
#
# Chain 0:  84%|████████▍ | 337/400 [00:02<00:00, 122.47it/s]
#
# Chain 0:  88%|████████▊ | 350/400 [00:02<00:00, 122.47it/s]
#
# Chain 0:  91%|█████████ | 363/400 [00:02<00:00, 122.47it/s]
#
# Chain 0:  94%|█████████▍| 376/400 [00:03<00:00, 122.51it/s]
#
# Chain 0: 100%|██████████| 400/400 [00:03<00:00, 122.26it/s]
#
#
# Chain 0:   0%|          | 0/400 [00:00<?, ?it/s]
#
# Chain 0:   3%|▎         | 12/400 [00:00<00:03, 116.63it/s]
#
# Chain 0:   6%|▋         | 25/400 [00:00<00:03, 120.11it/s]
#
# Chain 0:  10%|▉         | 38/400 [00:00<00:02, 121.11it/s]
#
# Chain 0:  13%|█▎        | 51/400 [00:00<00:02, 121.72it/s]
#
# Chain 0:  16%|█▌        | 64/400 [00:00<00:02, 122.02it/s]
#
# Chain 0:  19%|█▉        | 77/400 [00:00<00:02, 122.23it/s]
#
# Chain 0:  22%|██▎       | 90/400 [00:00<00:02, 122.38it/s]
#
# Chain 0:  26%|██▌       | 103/400 [00:00<00:02, 122.35it/s]
#
# Chain 0:  29%|██▉       | 116/400 [00:00<00:02, 122.36it/s]
#
# Chain 0:  32%|███▏      | 129/400 [00:01<00:02, 122.48it/s]

# %%
dataset = 0

def plot_losses(train_losses_final, test_losses_final, dataset):

    sns.set_style("whitegrid")

    fig, ax1 = plt.subplots(figsize=(10, 6))
    ax1.set_xlabel("Epoch")
    ax1.set_ylabel("Loss", color=PRIMARY)
    plt.yscale('log')
    ax1.plot(train_losses_final, label="Train Loss, sgd", color=PRIMARY)
    ax1.plot(test_losses_final, label="Test Loss, sgd", color=PRIMARY_LIGHT)
    ax1.tick_params(axis="y", labelcolor=PRIMARY)
    ax1.legend(loc="upper left")
    fig.tight_layout()
    plt.show()
    fig.savefig("losses_" + str(dataset) + "_" + str(N_EPOCHS) + "_epochs.png")

def plot_accuracies(train_accuracies_final, test_accuracies_final, dataset):

    sns.set_style("whitegrid")

    fig, ax1 = plt.subplots(figsize=(10, 6))
    ax1.set_xlabel("Epoch")
    ax1.set_ylabel("Accuracy", color=PRIMARY)
    plt.yscale('log')
    ax1.plot(train_accuracies_final, label="Train Accuracy, sgd", color=PRIMARY)
    ax1.plot(test_accuracies_final, label="Test Accuracy, sgd", color=PRIMARY_LIGHT)
    ax1.tick_params(axis="y", labelcolor=PRIMARY)
    ax1.legend(loc="upper left")
    fig.tight_layout()
    plt.show()
    fig.savefig("accuracies_" + str(dataset) + "_" + str(N_EPOCHS) + "_epochs.png")

def plot_rclts(rlct_estimates_final, dataset):

    sns.set_style("whitegrid")

    fig, ax2 = plt.subplots(figsize=(10, 6))
    ax2.set_xlabel("Epoch")
    ax2.set_ylabel(r"Local Learning Coefficient, $\hat \lambda$", color=SECONDARY)
    #ax2.plot(rlct_estimates_final["sgnht"], label="SGNHT, sgd", color=TERTIARY)
    ax2.plot(rlct_estimates_final["sgld"], label="SGLD, sgd", color=TERTIARY_LIGHT)
    ax2.tick_params(axis="y", labelcolor=SECONDARY)
    ax2.legend(loc="center right")

    fig.tight_layout()
    plt.show()
    fig.savefig("rclt_" + str(dataset) + "_" + str(N_EPOCHS) + "_epochs.png")

def plot_losses_chain(last_chain_losses_final, dataset):
    sns.set_style("whitegrid")


    fig, ax1 = plt.subplots(figsize=(10, 6))
    ax1.set_xlabel("Draw")
    ax1.set_ylabel("Loss", color=PRIMARY)
    ax1.plot(last_chain_losses_final, label="Loss, sgd", color=PRIMARY)
    ax1.tick_params(axis="y", labelcolor=PRIMARY)
    ax1.legend(loc="upper left")
    fig.tight_layout()
    plt.show()
    fig.savefig("last_chain_losses_" + str(dataset) + "_" + str(N_EPOCHS) + "_epochs.png")

plot_losses(train_losses_final, test_losses_final, dataset)
plot_accuracies(train_accuracies_final, test_accuracies_final, dataset)
plot_rclts(rlct_estimates_final, dataset)
plot_losses_chain(last_chain_losses_final, dataset)

# %%
world = Trainer(config=config)
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: shaffreybenjamin (uva-shaffrey-benjamin). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.17.3
# Run data is saved locally in <code>/gpfs/home1/bshaffrey/wandb/run-20240701_133309-ej7ytmsl</code>
# Syncing run <strong><a href='https://wandb.ai/uva-shaffrey-benjamin/grokking/runs/ej7ytmsl' target="_blank">lucky-durian-6</a></strong> to <a href='https://wandb.ai/uva-shaffrey-benjamin/grokking' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/uva-shaffrey-benjamin/grokking' target="_blank">https://wandb.ai/uva-shaffrey-benjamin/grokking</a>
#  View run at <a href='https://wandb.ai/uva-shaffrey-benjamin/grokking/runs/ej7ytmsl' target="_blank">https://wandb.ai/uva-shaffrey-benjamin/grokking/runs/ej7ytmsl</a>
# training length =  3830
# testing length =  8939

# %%
print(world.train_losses[ : 10])
# Out:
# []
